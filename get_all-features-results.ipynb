# %% [markdown]
# # get_all-features-results.ipynb
# This notebook:
# * Calculates the correlations between each set of features.
# * Defines the bonferroni-corrected alpha threshold, and filters out correlations which do not meet this criteria.
# * Filters out correlations with abs(c) < 0.1.
# * Writes the top 10 words for each topic into the df, if a topic variable has a significant correlation. This aids with interpretability of the topic (i.e., Topic 42 is interpreted by its top 10 words, not by "Topic 42").
#
# This happens on 2 versions of the df: (1) all the episodes for each show (approx. 80k episodes), (2) one episode per show (approx. 15k episodes).

# %%
import pandas as pd
import os
import json
from tqdm import tqdm
from scipy import stats
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# set pandas display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

def get_results_df(only_one_episode_per_show=False):
    
    csv_name = "./csv/df-all-features-results.csv"
    fig_name = "./fig-all_episodes.png"

    # read in df
    df = pd.read_csv("./csv/df-all-features.csv", index_col=0)
    # display(df.head())

    if only_one_episode_per_show:
        df = df.drop_duplicates(subset="show_uri", keep="first")
        csv_name = "./csv/df-all-features-one-show-per-episode-results.csv"
        fig_name = "./fig-one_episode.png"
    
    print("df length:", len(df))

    # print column names
    numeric_cols = df.select_dtypes(include='number').columns.tolist()
    print("Numeric columns:", numeric_cols)
    print("# of numeric columns:", len(numeric_cols), "\n")

    # calculate correlations and p-values
    results_lists = []
    for i in range(len(numeric_cols)-1):
        for j in range(i+1, len(numeric_cols)):
            attr1 = numeric_cols[i]
            attr2 = numeric_cols[j]
            correlation, pvalue = stats.pearsonr(x=df[attr1], y=df[attr2])
            results_lists.append([attr1, attr2, correlation, pvalue])
    results_df = pd.DataFrame(results_lists, columns=["attr1","attr2","correlation","pvalue"])
    num_tests_run = len(results_df)
    print("number of tests run:", num_tests_run)
    
    # # Create a heatmap
    # numeric_df = df.select_dtypes(include=np.number)
    # plt.figure(figsize=(120,120))
    # sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
    # plt.title('Correlation Heatmap of Numeric Columns')
    # plt.show()
    # plt.savefig(fig_name)

    # filter out correlations with low correlation values
    threshold = 0.1
    results_df = results_df[(results_df["correlation"] >= threshold) | (results_df["correlation"] <= -threshold)]
    
    # then round the correlation values to 2 decimal places
    results_df["correlation"] = results_df["correlation"].round(2)

    # filter out correlations with high p-value
    alpha_adjusted = 0.05/float(num_tests_run)
    print("alpha_adjusted:", alpha_adjusted)
    results_df = results_df[results_df["pvalue"] < alpha_adjusted]

    lda_topics = pd.read_csv("./LDA_topics.csv", header=None)

    def get_top_10_words(topic_num):
        l = ""
        for i in range(1,11):
            l += lda_topics.iloc[topic_num-1,i]  # subtract 1 because the index is 0-indexed, but topics are 1-indexed
            if i != 10:
                l += ", "
            else:
                l += " "
        return l


    results_df["attr1_topic_words"] = ""
    results_df["attr2_topic_words"] = ""

    for index, row in results_df.iterrows():

        if "Topic" in row["attr1"]:
            topic_num = int(row["attr1"].split("_")[1])
            results_df.loc[index,"attr1_topic_words"] = str(topic_num) + ": " + get_top_10_words(topic_num)

        if "Topic" in row["attr2"]:
            topic_num = int(row["attr2"].split("_")[1])
            results_df.loc[index,"attr2_topic_words"] = str(topic_num) + ": " + get_top_10_words(topic_num)

    display(results_df)

    # save
    results_df.to_csv(csv_name, header=True)

# %%
get_results_df(only_one_episode_per_show=False)
# Out:
# df length: 82601
# Numeric columns: ['duration', 'transcript_length', 'parse_INTJ_count', 'parse_EDITED_count', 'parse_PRN_count', 'parse_ADJP_count', 'parse_ADVP_count', 'parse_NP_count', 'parse_PP_count', 'parse_S_count', 'parse_SBAR_count', 'parse_SBARQ_count', 'parse_SINV_count', 'parse_SQ_count', 'parse_VP_count', 'parse_WHADVP_count', 'parse_WHNP_count', 'parse_WHPP_count', 'parse_X_count', 'female', 'male', 'music', 'noEnergy', 'noise', 'Topic_1_Probability', 'Topic_2_Probability', 'Topic_3_Probability', 'Topic_4_Probability', 'Topic_5_Probability', 'Topic_6_Probability', 'Topic_7_Probability', 'Topic_8_Probability', 'Topic_9_Probability', 'Topic_10_Probability', 'Topic_11_Probability', 'Topic_12_Probability', 'Topic_13_Probability', 'Topic_14_Probability', 'Topic_15_Probability', 'Topic_16_Probability', 'Topic_17_Probability', 'Topic_18_Probability', 'Topic_19_Probability', 'Topic_20_Probability', 'Topic_21_Probability', 'Topic_22_Probability', 'Topic_23_Probability', 'Topic_24_Probability', 'Topic_25_Probability', 'Topic_26_Probability', 'Topic_27_Probability', 'Topic_28_Probability', 'Topic_29_Probability', 'Topic_30_Probability', 'Topic_31_Probability', 'Topic_32_Probability', 'Topic_33_Probability', 'Topic_34_Probability', 'Topic_35_Probability', 'Topic_36_Probability', 'Topic_37_Probability', 'Topic_38_Probability', 'Topic_39_Probability', 'Topic_40_Probability', 'Topic_41_Probability', 'Topic_42_Probability', 'Topic_43_Probability', 'Topic_44_Probability', 'Topic_45_Probability', 'Topic_46_Probability', 'Topic_47_Probability', 'Topic_48_Probability', 'Topic_49_Probability', 'Topic_50_Probability', 'Topic_51_Probability', 'Topic_52_Probability', 'Topic_53_Probability', 'Topic_54_Probability', 'Topic_55_Probability', 'Topic_56_Probability', 'Topic_57_Probability', 'Topic_58_Probability', 'Topic_59_Probability', 'Topic_60_Probability', 'Topic_61_Probability', 'Topic_62_Probability', 'Topic_63_Probability', 'Topic_64_Probability', 'Topic_65_Probability', 'Topic_66_Probability', 'Topic_67_Probability', 'Topic_68_Probability', 'Topic_69_Probability', 'Topic_70_Probability', 'Topic_71_Probability', 'Topic_72_Probability', 'Topic_73_Probability', 'Topic_74_Probability', 'Topic_75_Probability', 'Topic_76_Probability', 'Topic_77_Probability', 'Topic_78_Probability', 'Topic_79_Probability', 'Topic_80_Probability', 'Topic_81_Probability', 'Topic_82_Probability', 'Topic_83_Probability', 'Topic_84_Probability', 'Topic_85_Probability', 'Topic_86_Probability', 'Topic_87_Probability', 'Topic_88_Probability', 'Topic_89_Probability', 'Topic_90_Probability', 'Topic_91_Probability', 'Topic_92_Probability', 'Topic_93_Probability', 'Topic_94_Probability', 'Topic_95_Probability', 'Topic_96_Probability', 'Topic_97_Probability', 'Topic_98_Probability', 'Topic_99_Probability', 'Topic_100_Probability']
# # of numeric columns: 124
#
# number of tests run: 7626
# alpha_adjusted: 6.5565171780750066e-06
#                      attr1                  attr2  correlation         pvalue  \
# 0                 duration      transcript_length         0.14   0.000000e+00
# 1                 duration       parse_INTJ_count         0.32   0.000000e+00
# 2                 duration     parse_EDITED_count         0.27   0.000000e+00
# 3                 duration        parse_PRN_count         0.16   0.000000e+00
# 5                 duration       parse_ADVP_count         0.16   0.000000e+00
# 6                 duration         parse_NP_count         0.15   0.000000e+00
# 8                 duration          parse_S_count         0.10  1.002638e-191
# 10                duration      parse_SBARQ_count         0.12  1.561062e-250
# 12                duration         parse_SQ_count         0.17   0.000000e+00
# 31                duration    Topic_9_Probability        -0.20   0.000000e+00
# 53                duration   Topic_31_Probability         0.11  2.523095e-210
# 82                duration   Topic_60_Probability         0.16   0.000000e+00
# 84                duration   Topic_62_Probability        -0.22   0.000000e+00
# 117               duration   Topic_95_Probability        -0.11  1.449198e-220
# 122               duration  Topic_100_Probability         0.29   0.000000e+00
# 123      transcript_length       parse_INTJ_count         0.34   0.000000e+00
# 124      transcript_length     parse_EDITED_count         0.39   0.000000e+00
# 125      transcript_length        parse_PRN_count         0.33   0.000000e+00
# 126      transcript_length       parse_ADJP_count         0.50   0.000000e+00
# 127      transcript_length       parse_ADVP_count         0.69   0.000000e+00
# 128      transcript_length         parse_NP_count         0.94   0.000000e+00
# 129      transcript_length         parse_PP_count         0.53   0.000000e+00
# 130      transcript_length          parse_S_count         0.85   0.000000e+00
# 131      transcript_length       parse_SBAR_count         0.68   0.000000e+00
# 132      transcript_length      parse_SBARQ_count         0.23   0.000000e+00
# 134      transcript_length         parse_SQ_count         0.26   0.000000e+00
# 135      transcript_length         parse_VP_count         0.86   0.000000e+00
# 136      transcript_length     parse_WHADVP_count         0.40   0.000000e+00
# 137      transcript_length       parse_WHNP_count         0.41   0.000000e+00
# 141      transcript_length                   male         0.14   0.000000e+00
# 143      transcript_length               noEnergy        -0.15   0.000000e+00
# 144      transcript_length                  noise        -0.13  2.465585e-319
# 149      transcript_length    Topic_5_Probability        -0.12  2.884467e-284
# 153      transcript_length    Topic_9_Probability        -0.22   0.000000e+00
# 154      transcript_length   Topic_10_Probability        -0.28   0.000000e+00
# 155      transcript_length   Topic_11_Probability        -0.16   0.000000e+00
# 193      transcript_length   Topic_49_Probability         0.15   0.000000e+00
# 197      transcript_length   Topic_53_Probability        -0.23   0.000000e+00
# 202      transcript_length   Topic_58_Probability        -0.14   0.000000e+00
# 204      transcript_length   Topic_60_Probability         0.17   0.000000e+00
# 207      transcript_length   Topic_63_Probability        -0.16   0.000000e+00
# 232      transcript_length   Topic_88_Probability        -0.22   0.000000e+00
# 239      transcript_length   Topic_95_Probability        -0.35   0.000000e+00
# 244      transcript_length  Topic_100_Probability         0.19   0.000000e+00
# 245       parse_INTJ_count     parse_EDITED_count         0.48   0.000000e+00
# 246       parse_INTJ_count        parse_PRN_count         0.27   0.000000e+00
# 247       parse_INTJ_count       parse_ADJP_count         0.29   0.000000e+00
# 248       parse_INTJ_count       parse_ADVP_count         0.39   0.000000e+00
# 249       parse_INTJ_count         parse_NP_count         0.29   0.000000e+00
# 250       parse_INTJ_count         parse_PP_count        -0.30   0.000000e+00
# 251       parse_INTJ_count          parse_S_count         0.37   0.000000e+00
# 252       parse_INTJ_count       parse_SBAR_count         0.10  7.382292e-201
# 253       parse_INTJ_count      parse_SBARQ_count         0.39   0.000000e+00
# 255       parse_INTJ_count         parse_SQ_count         0.48   0.000000e+00
# 256       parse_INTJ_count         parse_VP_count         0.33   0.000000e+00
# 257       parse_INTJ_count     parse_WHADVP_count         0.13  2.303987e-295
# 259       parse_INTJ_count       parse_WHPP_count        -0.15   0.000000e+00
# 270       parse_INTJ_count    Topic_5_Probability        -0.13  1.669856e-301
# 274       parse_INTJ_count    Topic_9_Probability        -0.37   0.000000e+00
# 275       parse_INTJ_count   Topic_10_Probability        -0.14   0.000000e+00
# 276       parse_INTJ_count   Topic_11_Probability        -0.25   0.000000e+00
# 277       parse_INTJ_count   Topic_12_Probability        -0.14   0.000000e+00
# 296       parse_INTJ_count   Topic_31_Probability         0.14   0.000000e+00
# 299       parse_INTJ_count   Topic_34_Probability        -0.11  2.769825e-226
# 318       parse_INTJ_count   Topic_53_Probability        -0.26   0.000000e+00
# 319       parse_INTJ_count   Topic_54_Probability        -0.12  2.026390e-270
# 327       parse_INTJ_count   Topic_62_Probability        -0.12  6.832414e-253
# 328       parse_INTJ_count   Topic_63_Probability        -0.18   0.000000e+00
# 353       parse_INTJ_count   Topic_88_Probability        -0.22   0.000000e+00
# 360       parse_INTJ_count   Topic_95_Probability        -0.23   0.000000e+00
# 365       parse_INTJ_count  Topic_100_Probability         0.86   0.000000e+00
# 366     parse_EDITED_count        parse_PRN_count         0.51   0.000000e+00
# 367     parse_EDITED_count       parse_ADJP_count         0.17   0.000000e+00
# 368     parse_EDITED_count       parse_ADVP_count         0.39   0.000000e+00
# 369     parse_EDITED_count         parse_NP_count         0.37   0.000000e+00
# 371     parse_EDITED_count          parse_S_count         0.41   0.000000e+00
# 372     parse_EDITED_count       parse_SBAR_count         0.24   0.000000e+00
# 373     parse_EDITED_count      parse_SBARQ_count         0.19   0.000000e+00
# 375     parse_EDITED_count         parse_SQ_count         0.20   0.000000e+00
# 376     parse_EDITED_count         parse_VP_count         0.39   0.000000e+00
# 377     parse_EDITED_count     parse_WHADVP_count         0.17   0.000000e+00
# 378     parse_EDITED_count       parse_WHNP_count         0.15   0.000000e+00
# 379     parse_EDITED_count       parse_WHPP_count        -0.13  1.475844e-299
# 381     parse_EDITED_count                 female        -0.12  1.277964e-260
# 382     parse_EDITED_count                   male         0.10  7.948938e-190
# 390     parse_EDITED_count    Topic_5_Probability        -0.15   0.000000e+00
# 394     parse_EDITED_count    Topic_9_Probability        -0.26   0.000000e+00
# 395     parse_EDITED_count   Topic_10_Probability        -0.12  1.563995e-264
# 396     parse_EDITED_count   Topic_11_Probability        -0.22   0.000000e+00
# 434     parse_EDITED_count   Topic_49_Probability         0.14   0.000000e+00
# 438     parse_EDITED_count   Topic_53_Probability        -0.31   0.000000e+00
# 445     parse_EDITED_count   Topic_60_Probability         0.16   0.000000e+00
# 448     parse_EDITED_count   Topic_63_Probability        -0.16   0.000000e+00
# 473     parse_EDITED_count   Topic_88_Probability        -0.27   0.000000e+00
# 480     parse_EDITED_count   Topic_95_Probability        -0.29   0.000000e+00
# 485     parse_EDITED_count  Topic_100_Probability         0.40   0.000000e+00
# 486        parse_PRN_count       parse_ADJP_count         0.13  8.862682e-307
# 487        parse_PRN_count       parse_ADVP_count         0.38   0.000000e+00
# 488        parse_PRN_count         parse_NP_count         0.34   0.000000e+00
# 490        parse_PRN_count          parse_S_count         0.36   0.000000e+00
# 491        parse_PRN_count       parse_SBAR_count         0.22   0.000000e+00
# 492        parse_PRN_count      parse_SBARQ_count         0.10  6.837911e-186
# 495        parse_PRN_count         parse_VP_count         0.34   0.000000e+00
# 496        parse_PRN_count     parse_WHADVP_count         0.14   0.000000e+00
# 497        parse_PRN_count       parse_WHNP_count         0.16   0.000000e+00
# 498        parse_PRN_count       parse_WHPP_count        -0.11  2.126520e-210
# 509        parse_PRN_count    Topic_5_Probability        -0.12  4.342393e-278
# 513        parse_PRN_count    Topic_9_Probability        -0.22   0.000000e+00
# 514        parse_PRN_count   Topic_10_Probability        -0.11  7.095902e-231
# 515        parse_PRN_count   Topic_11_Probability        -0.18   0.000000e+00
# 553        parse_PRN_count   Topic_49_Probability         0.20   0.000000e+00
# 557        parse_PRN_count   Topic_53_Probability        -0.25   0.000000e+00
# 563        parse_PRN_count   Topic_59_Probability        -0.10  1.217050e-198
# 564        parse_PRN_count   Topic_60_Probability         0.15   0.000000e+00
# 567        parse_PRN_count   Topic_63_Probability        -0.13  6.950769e-302
# 592        parse_PRN_count   Topic_88_Probability        -0.27   0.000000e+00
# 599        parse_PRN_count   Topic_95_Probability        -0.26   0.000000e+00
# 604        parse_PRN_count  Topic_100_Probability         0.22   0.000000e+00
# 605       parse_ADJP_count       parse_ADVP_count         0.40   0.000000e+00
# 606       parse_ADJP_count         parse_NP_count         0.41   0.000000e+00
# 607       parse_ADJP_count         parse_PP_count         0.10  3.007255e-195
# 608       parse_ADJP_count          parse_S_count         0.52   0.000000e+00
# 609       parse_ADJP_count       parse_SBAR_count         0.41   0.000000e+00
# 610       parse_ADJP_count      parse_SBARQ_count         0.13  4.918084e-289
# 612       parse_ADJP_count         parse_SQ_count         0.17   0.000000e+00
# 613       parse_ADJP_count         parse_VP_count         0.48   0.000000e+00
# 614       parse_ADJP_count     parse_WHADVP_count         0.21   0.000000e+00
# 615       parse_ADJP_count       parse_WHNP_count         0.17   0.000000e+00
# 618       parse_ADJP_count                 female         0.12  3.570833e-279
# 627       parse_ADJP_count    Topic_5_Probability        -0.13  9.881313e-323
# 632       parse_ADJP_count   Topic_10_Probability        -0.12  2.943817e-280
# 633       parse_ADJP_count   Topic_11_Probability        -0.17   0.000000e+00
# 675       parse_ADJP_count   Topic_53_Probability        -0.19   0.000000e+00
# 679       parse_ADJP_count   Topic_57_Probability        -0.11  1.298536e-201
# 681       parse_ADJP_count   Topic_59_Probability        -0.12  2.408922e-249
# 684       parse_ADJP_count   Topic_62_Probability         0.23   0.000000e+00
# 685       parse_ADJP_count   Topic_63_Probability        -0.16   0.000000e+00
# 710       parse_ADJP_count   Topic_88_Probability        -0.21   0.000000e+00
# 717       parse_ADJP_count   Topic_95_Probability        -0.17   0.000000e+00
# 722       parse_ADJP_count  Topic_100_Probability         0.20   0.000000e+00
# 723       parse_ADVP_count         parse_NP_count         0.60   0.000000e+00
# 724       parse_ADVP_count         parse_PP_count         0.20   0.000000e+00
# 725       parse_ADVP_count          parse_S_count         0.60   0.000000e+00
# 726       parse_ADVP_count       parse_SBAR_count         0.47   0.000000e+00
# 727       parse_ADVP_count      parse_SBARQ_count         0.13   0.000000e+00
# 729       parse_ADVP_count         parse_SQ_count         0.18   0.000000e+00
# 730       parse_ADVP_count         parse_VP_count         0.62   0.000000e+00
# 731       parse_ADVP_count     parse_WHADVP_count         0.28   0.000000e+00
# 732       parse_ADVP_count       parse_WHNP_count         0.25   0.000000e+00
# 733       parse_ADVP_count       parse_WHPP_count        -0.14   0.000000e+00
# 738       parse_ADVP_count               noEnergy        -0.10  3.888326e-185
# 743       parse_ADVP_count    Topic_4_Probability        -0.12  2.569993e-244
# 744       parse_ADVP_count    Topic_5_Probability        -0.18   0.000000e+00
# 748       parse_ADVP_count    Topic_9_Probability        -0.29   0.000000e+00
# 749       parse_ADVP_count   Topic_10_Probability        -0.17   0.000000e+00
# 750       parse_ADVP_count   Topic_11_Probability        -0.26   0.000000e+00
# 773       parse_ADVP_count   Topic_34_Probability        -0.14   0.000000e+00
# 788       parse_ADVP_count   Topic_49_Probability         0.12  3.150411e-241
# 792       parse_ADVP_count   Topic_53_Probability        -0.30   0.000000e+00
# 796       parse_ADVP_count   Topic_57_Probability        -0.13  3.518344e-291
# 797       parse_ADVP_count   Topic_58_Probability        -0.10  3.761825e-184
# 798       parse_ADVP_count   Topic_59_Probability        -0.17   0.000000e+00
# 799       parse_ADVP_count   Topic_60_Probability         0.28   0.000000e+00
# 801       parse_ADVP_count   Topic_62_Probability         0.10  1.551948e-184
# 802       parse_ADVP_count   Topic_63_Probability        -0.23   0.000000e+00
# 805       parse_ADVP_count   Topic_66_Probability        -0.12  2.684238e-260
# 806       parse_ADVP_count   Topic_67_Probability         0.11  2.829942e-234
# 827       parse_ADVP_count   Topic_88_Probability        -0.33   0.000000e+00
# 834       parse_ADVP_count   Topic_95_Probability        -0.28   0.000000e+00
# 839       parse_ADVP_count  Topic_100_Probability         0.26   0.000000e+00
# 840         parse_NP_count         parse_PP_count         0.55   0.000000e+00
# 841         parse_NP_count          parse_S_count         0.77   0.000000e+00
# 842         parse_NP_count       parse_SBAR_count         0.61   0.000000e+00
# 843         parse_NP_count      parse_SBARQ_count         0.19   0.000000e+00
# 845         parse_NP_count         parse_SQ_count         0.23   0.000000e+00
# 846         parse_NP_count         parse_VP_count         0.77   0.000000e+00
# 847         parse_NP_count     parse_WHADVP_count         0.35   0.000000e+00
# 848         parse_NP_count       parse_WHNP_count         0.42   0.000000e+00
# 852         parse_NP_count                   male         0.17   0.000000e+00
# 854         parse_NP_count               noEnergy        -0.15   0.000000e+00
# 855         parse_NP_count                  noise        -0.12  3.003031e-267
# 864         parse_NP_count    Topic_9_Probability        -0.21   0.000000e+00
# 865         parse_NP_count   Topic_10_Probability        -0.28   0.000000e+00
# 866         parse_NP_count   Topic_11_Probability        -0.13  2.043644e-299
# 886         parse_NP_count   Topic_31_Probability         0.13  3.186521e-294
# 904         parse_NP_count   Topic_49_Probability         0.14   0.000000e+00
# 908         parse_NP_count   Topic_53_Probability        -0.17   0.000000e+00
# 913         parse_NP_count   Topic_58_Probability        -0.14   0.000000e+00
# 915         parse_NP_count   Topic_60_Probability         0.14   0.000000e+00
# 918         parse_NP_count   Topic_63_Probability        -0.11  2.064038e-221
# 943         parse_NP_count   Topic_88_Probability        -0.14   0.000000e+00
# 950         parse_NP_count   Topic_95_Probability        -0.34   0.000000e+00
# 955         parse_NP_count  Topic_100_Probability         0.17   0.000000e+00
# 956         parse_PP_count          parse_S_count         0.21   0.000000e+00
# 957         parse_PP_count       parse_SBAR_count         0.28   0.000000e+00
# 958         parse_PP_count      parse_SBARQ_count        -0.12  3.605069e-261
# 960         parse_PP_count         parse_SQ_count        -0.15   0.000000e+00
# 961         parse_PP_count         parse_VP_count         0.24   0.000000e+00
# 962         parse_PP_count     parse_WHADVP_count         0.14   0.000000e+00
# 963         parse_PP_count       parse_WHNP_count         0.23   0.000000e+00
# 964         parse_PP_count       parse_WHPP_count         0.14   0.000000e+00
# 966         parse_PP_count                 female        -0.11  1.723709e-201
# 967         parse_PP_count                   male         0.18   0.000000e+00
# 969         parse_PP_count               noEnergy        -0.11  1.262003e-224
# 979         parse_PP_count    Topic_9_Probability         0.16   0.000000e+00
# 980         parse_PP_count   Topic_10_Probability        -0.13  2.404747e-311
# 981         parse_PP_count   Topic_11_Probability         0.18   0.000000e+00
# 982         parse_PP_count   Topic_12_Probability         0.12  3.423675e-262
# 1004        parse_PP_count   Topic_34_Probability         0.10  1.839661e-189
# 1019        parse_PP_count   Topic_49_Probability         0.14   0.000000e+00
# 1023        parse_PP_count   Topic_53_Probability         0.12  1.140858e-262
# 1030        parse_PP_count   Topic_60_Probability         0.12  3.549928e-280
# 1033        parse_PP_count   Topic_63_Probability         0.13   0.000000e+00
# 1037        parse_PP_count   Topic_67_Probability         0.23   0.000000e+00
# 1041        parse_PP_count   Topic_71_Probability        -0.13  9.161716e-318
# 1070        parse_PP_count  Topic_100_Probability        -0.42   0.000000e+00
# 1071         parse_S_count       parse_SBAR_count         0.87   0.000000e+00
# 1072         parse_S_count      parse_SBARQ_count         0.33   0.000000e+00
# 1074         parse_S_count         parse_SQ_count         0.35   0.000000e+00
# 1075         parse_S_count         parse_VP_count         0.95   0.000000e+00
# 1076         parse_S_count     parse_WHADVP_count         0.53   0.000000e+00
# 1077         parse_S_count       parse_WHNP_count         0.51   0.000000e+00
# 1078         parse_S_count       parse_WHPP_count        -0.14   0.000000e+00
# 1083         parse_S_count               noEnergy        -0.13  2.389635e-289
# 1084         parse_S_count                  noise        -0.12  6.187043e-262
# 1088         parse_S_count    Topic_4_Probability        -0.12  1.984997e-250
# 1089         parse_S_count    Topic_5_Probability        -0.17   0.000000e+00
# 1091         parse_S_count    Topic_7_Probability        -0.10  4.527542e-198
# 1093         parse_S_count    Topic_9_Probability        -0.22   0.000000e+00
# 1094         parse_S_count   Topic_10_Probability        -0.21   0.000000e+00
# 1095         parse_S_count   Topic_11_Probability        -0.29   0.000000e+00
# 1118         parse_S_count   Topic_34_Probability        -0.19   0.000000e+00
# 1137         parse_S_count   Topic_53_Probability        -0.34   0.000000e+00
# 1141         parse_S_count   Topic_57_Probability        -0.12  1.182585e-249
# 1142         parse_S_count   Topic_58_Probability        -0.13  6.422853e-322
# 1146         parse_S_count   Topic_62_Probability         0.32   0.000000e+00
# 1147         parse_S_count   Topic_63_Probability        -0.25   0.000000e+00
# 1150         parse_S_count   Topic_66_Probability        -0.14   0.000000e+00
# 1172         parse_S_count   Topic_88_Probability        -0.21   0.000000e+00
# 1179         parse_S_count   Topic_95_Probability        -0.40   0.000000e+00
# 1184         parse_S_count  Topic_100_Probability         0.26   0.000000e+00
# 1185      parse_SBAR_count      parse_SBARQ_count         0.24   0.000000e+00
# 1187      parse_SBAR_count         parse_SQ_count         0.20   0.000000e+00
# 1188      parse_SBAR_count         parse_VP_count         0.77   0.000000e+00
# 1189      parse_SBAR_count     parse_WHADVP_count         0.59   0.000000e+00
# 1190      parse_SBAR_count       parse_WHNP_count         0.64   0.000000e+00
# 1196      parse_SBAR_count               noEnergy        -0.13  1.092133e-289
# 1197      parse_SBAR_count                  noise        -0.12  2.680620e-259
# 1202      parse_SBAR_count    Topic_5_Probability        -0.14   0.000000e+00
# 1204      parse_SBAR_count    Topic_7_Probability        -0.11  1.340748e-238
# 1207      parse_SBAR_count   Topic_10_Probability        -0.15   0.000000e+00
# 1208      parse_SBAR_count   Topic_11_Probability        -0.19   0.000000e+00
# 1231      parse_SBAR_count   Topic_34_Probability        -0.15   0.000000e+00
# 1250      parse_SBAR_count   Topic_53_Probability        -0.32   0.000000e+00
# 1254      parse_SBAR_count   Topic_57_Probability        -0.10  1.112200e-182
# 1255      parse_SBAR_count   Topic_58_Probability        -0.11  6.262534e-222
# 1259      parse_SBAR_count   Topic_62_Probability         0.41   0.000000e+00
# 1260      parse_SBAR_count   Topic_63_Probability        -0.17   0.000000e+00
# 1263      parse_SBAR_count   Topic_66_Probability        -0.14   0.000000e+00
# 1268      parse_SBAR_count   Topic_71_Probability        -0.10  5.675302e-184
# 1285      parse_SBAR_count   Topic_88_Probability        -0.18   0.000000e+00
# 1292      parse_SBAR_count   Topic_95_Probability        -0.36   0.000000e+00
# 1299     parse_SBARQ_count         parse_SQ_count         0.82   0.000000e+00
# 1300     parse_SBARQ_count         parse_VP_count         0.23   0.000000e+00
# 1301     parse_SBARQ_count     parse_WHADVP_count         0.33   0.000000e+00
# 1302     parse_SBARQ_count       parse_WHNP_count         0.29   0.000000e+00
# 1318     parse_SBARQ_count    Topic_9_Probability        -0.15   0.000000e+00
# 1320     parse_SBARQ_count   Topic_11_Probability        -0.12  4.527953e-277
# 1362     parse_SBARQ_count   Topic_53_Probability        -0.20   0.000000e+00
# 1404     parse_SBARQ_count   Topic_95_Probability        -0.19   0.000000e+00
# 1409     parse_SBARQ_count  Topic_100_Probability         0.34   0.000000e+00
# 1508      parse_SINV_count   Topic_88_Probability         0.11  2.429546e-228
# 1521        parse_SQ_count         parse_VP_count         0.25   0.000000e+00
# 1522        parse_SQ_count     parse_WHADVP_count         0.24   0.000000e+00
# 1523        parse_SQ_count       parse_WHNP_count         0.19   0.000000e+00
# 1539        parse_SQ_count    Topic_9_Probability        -0.21   0.000000e+00
# 1540        parse_SQ_count   Topic_10_Probability        -0.11  1.068756e-209
# 1541        parse_SQ_count   Topic_11_Probability        -0.14   0.000000e+00
# 1560        parse_SQ_count   Topic_30_Probability         0.15   0.000000e+00
# 1583        parse_SQ_count   Topic_53_Probability        -0.20   0.000000e+00
# 1588        parse_SQ_count   Topic_58_Probability        -0.11  2.462671e-221
# 1593        parse_SQ_count   Topic_63_Probability        -0.11  5.954235e-218
# 1625        parse_SQ_count   Topic_95_Probability        -0.18   0.000000e+00
# 1630        parse_SQ_count  Topic_100_Probability         0.41   0.000000e+00
# 1631        parse_VP_count     parse_WHADVP_count         0.44   0.000000e+00
# 1632        parse_VP_count       parse_WHNP_count         0.44   0.000000e+00
# 1633        parse_VP_count       parse_WHPP_count        -0.14   0.000000e+00
# 1638        parse_VP_count               noEnergy        -0.12  1.484169e-270
# 1639        parse_VP_count                  noise        -0.12  1.638883e-253
# 1643        parse_VP_count    Topic_4_Probability        -0.12  2.015980e-278
# 1644        parse_VP_count    Topic_5_Probability        -0.17   0.000000e+00
# 1648        parse_VP_count    Topic_9_Probability        -0.22   0.000000e+00
# 1649        parse_VP_count   Topic_10_Probability        -0.21   0.000000e+00
# 1650        parse_VP_count   Topic_11_Probability        -0.29   0.000000e+00
# 1673        parse_VP_count   Topic_34_Probability        -0.18   0.000000e+00
# 1692        parse_VP_count   Topic_53_Probability        -0.32   0.000000e+00
# 1696        parse_VP_count   Topic_57_Probability        -0.14   0.000000e+00
# 1697        parse_VP_count   Topic_58_Probability        -0.10  5.217286e-187
# 1701        parse_VP_count   Topic_62_Probability         0.29   0.000000e+00
# 1702        parse_VP_count   Topic_63_Probability        -0.26   0.000000e+00
# 1705        parse_VP_count   Topic_66_Probability        -0.13   0.000000e+00
# 1727        parse_VP_count   Topic_88_Probability        -0.21   0.000000e+00
# 1734        parse_VP_count   Topic_95_Probability        -0.36   0.000000e+00
# 1739        parse_VP_count  Topic_100_Probability         0.22   0.000000e+00
# 1740    parse_WHADVP_count       parse_WHNP_count         0.32   0.000000e+00
# 1758    parse_WHADVP_count   Topic_11_Probability        -0.14   0.000000e+00
# 1781    parse_WHADVP_count   Topic_34_Probability        -0.11  1.214610e-232
# 1796    parse_WHADVP_count   Topic_49_Probability        -0.11  6.918785e-223
# 1800    parse_WHADVP_count   Topic_53_Probability        -0.18   0.000000e+00
# 1807    parse_WHADVP_count   Topic_60_Probability        -0.15   0.000000e+00
# 1809    parse_WHADVP_count   Topic_62_Probability         0.34   0.000000e+00
# 1810    parse_WHADVP_count   Topic_63_Probability        -0.12  1.138677e-264
# 1814    parse_WHADVP_count   Topic_67_Probability         0.17   0.000000e+00
# 1835    parse_WHADVP_count   Topic_88_Probability        -0.16   0.000000e+00
# 1842    parse_WHADVP_count   Topic_95_Probability        -0.22   0.000000e+00
# 1859      parse_WHNP_count    Topic_5_Probability        -0.11  3.939620e-236
# 1863      parse_WHNP_count    Topic_9_Probability         0.10  2.027853e-196
# 1866      parse_WHNP_count   Topic_12_Probability         0.10  5.553915e-189
# 1907      parse_WHNP_count   Topic_53_Probability        -0.29   0.000000e+00
# 1908      parse_WHNP_count   Topic_54_Probability         0.12  4.163142e-272
# 1912      parse_WHNP_count   Topic_58_Probability        -0.11  1.099660e-202
# 1916      parse_WHNP_count   Topic_62_Probability         0.28   0.000000e+00
# 1921      parse_WHNP_count   Topic_67_Probability         0.12  3.220740e-268
# 1925      parse_WHNP_count   Topic_71_Probability        -0.10  2.023489e-185
# 1942      parse_WHNP_count   Topic_88_Probability        -0.15   0.000000e+00
# 1949      parse_WHNP_count   Topic_95_Probability        -0.28   0.000000e+00
# 1969      parse_WHPP_count    Topic_9_Probability         0.19   0.000000e+00
# 1971      parse_WHPP_count   Topic_11_Probability         0.16   0.000000e+00
# 2013      parse_WHPP_count   Topic_53_Probability         0.12  2.663501e-249
# 2023      parse_WHPP_count   Topic_63_Probability         0.16   0.000000e+00
# 2048      parse_WHPP_count   Topic_88_Probability         0.15   0.000000e+00
# 2060      parse_WHPP_count  Topic_100_Probability        -0.15   0.000000e+00
# 2166                female                   male        -0.76   0.000000e+00
# 2167                female                  music        -0.22   0.000000e+00
# 2172                female    Topic_3_Probability         0.12  4.939745e-281
# 2179                female   Topic_10_Probability         0.13  1.458937e-290
# 2218                female   Topic_49_Probability        -0.21   0.000000e+00
# 2229                female   Topic_60_Probability        -0.29   0.000000e+00
# 2231                female   Topic_62_Probability         0.32   0.000000e+00
# 2240                female   Topic_71_Probability         0.11  2.543866e-229
# 2248                female   Topic_79_Probability        -0.11  5.589883e-235
# 2270                  male                  music        -0.41   0.000000e+00
# 2272                  male                  noise        -0.13  4.001371e-309
# 2282                  male   Topic_10_Probability        -0.12  9.846421e-245
# 2284                  male   Topic_12_Probability         0.12  5.020025e-259
# 2321                  male   Topic_49_Probability         0.13  3.701479e-288
# 2326                  male   Topic_54_Probability         0.13  1.302264e-305
# 2332                  male   Topic_60_Probability         0.18   0.000000e+00
# 2334                  male   Topic_62_Probability        -0.25   0.000000e+00
# 2343                  male   Topic_71_Probability        -0.14   0.000000e+00
# 2373                 music               noEnergy        -0.12  6.141976e-268
# 2432                 music   Topic_58_Probability        -0.12  1.849923e-274
# 2434                 music   Topic_60_Probability         0.12  1.979536e-284
# 2570              noEnergy   Topic_95_Probability         0.10  4.360906e-196
# 2708   Topic_1_Probability   Topic_34_Probability         0.19   0.000000e+00
# 2929   Topic_3_Probability   Topic_60_Probability        -0.13  1.733190e-298
# 2931   Topic_3_Probability   Topic_62_Probability         0.13  3.621304e-319
# 2940   Topic_3_Probability   Topic_71_Probability         0.11  2.624175e-239
# 3022   Topic_4_Probability   Topic_57_Probability         0.23   0.000000e+00
# 3024   Topic_4_Probability   Topic_59_Probability         0.32   0.000000e+00
# 3053   Topic_4_Probability   Topic_88_Probability         0.14   0.000000e+00
# 3058   Topic_4_Probability   Topic_93_Probability         0.38   0.000000e+00
# 3071   Topic_5_Probability   Topic_11_Probability         0.15   0.000000e+00
# 3087   Topic_5_Probability   Topic_27_Probability         0.19   0.000000e+00
# 3092   Topic_5_Probability   Topic_32_Probability         0.11  1.713477e-231
# 3113   Topic_5_Probability   Topic_53_Probability         0.46   0.000000e+00
# 3122   Topic_5_Probability   Topic_62_Probability        -0.10  4.428995e-190
# 3123   Topic_5_Probability   Topic_63_Probability         0.10  6.039674e-194
# 3148   Topic_5_Probability   Topic_88_Probability         0.29   0.000000e+00
# 3221   Topic_6_Probability   Topic_67_Probability         0.27   0.000000e+00
# 3309   Topic_7_Probability   Topic_62_Probability        -0.11  2.956388e-205
# 3342   Topic_7_Probability   Topic_95_Probability         0.19   0.000000e+00
# 3440   Topic_9_Probability   Topic_10_Probability         0.25   0.000000e+00
# 3441   Topic_9_Probability   Topic_11_Probability         0.18   0.000000e+00
# 3461   Topic_9_Probability   Topic_31_Probability        -0.14   0.000000e+00
# 3464   Topic_9_Probability   Topic_34_Probability         0.14   0.000000e+00
# 3479   Topic_9_Probability   Topic_49_Probability        -0.16   0.000000e+00
# 3490   Topic_9_Probability   Topic_60_Probability        -0.17   0.000000e+00
# 3492   Topic_9_Probability   Topic_62_Probability         0.13  2.108352e-302
# 3501   Topic_9_Probability   Topic_71_Probability        -0.14   0.000000e+00
# 3515   Topic_9_Probability   Topic_85_Probability         0.13  8.717555e-301
# 3530   Topic_9_Probability  Topic_100_Probability        -0.38   0.000000e+00
# 3580  Topic_10_Probability   Topic_60_Probability        -0.11  7.128718e-222
# 3582  Topic_10_Probability   Topic_62_Probability         0.11  6.424307e-214
# 3615  Topic_10_Probability   Topic_95_Probability         0.32   0.000000e+00
# 3620  Topic_10_Probability  Topic_100_Probability        -0.13  8.237882e-315
# 3621  Topic_11_Probability   Topic_12_Probability         0.23   0.000000e+00
# 3643  Topic_11_Probability   Topic_34_Probability         0.10  1.023921e-185
# 3662  Topic_11_Probability   Topic_53_Probability         0.23   0.000000e+00
# 3671  Topic_11_Probability   Topic_62_Probability        -0.23   0.000000e+00
# 3672  Topic_11_Probability   Topic_63_Probability         0.36   0.000000e+00
# 3675  Topic_11_Probability   Topic_66_Probability         0.17   0.000000e+00
# 3681  Topic_11_Probability   Topic_72_Probability         0.18   0.000000e+00
# 3709  Topic_11_Probability  Topic_100_Probability        -0.23   0.000000e+00
# 3728  Topic_12_Probability   Topic_31_Probability        -0.11  1.943018e-220
# 3751  Topic_12_Probability   Topic_54_Probability         0.29   0.000000e+00
# 3764  Topic_12_Probability   Topic_67_Probability         0.13  3.383948e-314
# 3769  Topic_12_Probability   Topic_72_Probability         0.15   0.000000e+00
# 3785  Topic_12_Probability   Topic_88_Probability        -0.12  8.300379e-265
# 3792  Topic_12_Probability   Topic_95_Probability        -0.11  5.271545e-226
# 3797  Topic_12_Probability  Topic_100_Probability        -0.18   0.000000e+00
# 3833  Topic_13_Probability   Topic_49_Probability         0.13  3.280782e-294
# 3844  Topic_13_Probability   Topic_60_Probability         0.13  1.402701e-302
# 3864  Topic_13_Probability   Topic_80_Probability         0.33   0.000000e+00
# 4257  Topic_18_Probability   Topic_53_Probability         0.14   0.000000e+00
# 4414  Topic_20_Probability   Topic_49_Probability         0.43   0.000000e+00
# 4425  Topic_20_Probability   Topic_60_Probability         0.11  1.803741e-203
# 4427  Topic_20_Probability   Topic_62_Probability        -0.11  7.186940e-234
# 4593  Topic_22_Probability   Topic_71_Probability         0.11  1.682248e-207
# 4607  Topic_22_Probability   Topic_85_Probability         0.10  8.382742e-187
# 4622  Topic_22_Probability  Topic_100_Probability         0.12  2.099450e-243
# 4633  Topic_23_Probability   Topic_34_Probability         0.12  2.492830e-251
# 4797  Topic_25_Probability   Topic_47_Probability         0.18   0.000000e+00
# 4799  Topic_25_Probability   Topic_49_Probability         0.30   0.000000e+00
# 4812  Topic_25_Probability   Topic_62_Probability        -0.13  1.864937e-298
# 4929  Topic_27_Probability   Topic_32_Probability         0.15   0.000000e+00
# 4942  Topic_27_Probability   Topic_45_Probability         0.23   0.000000e+00
# 4969  Topic_27_Probability   Topic_72_Probability         0.22   0.000000e+00
# 5170  Topic_30_Probability   Topic_60_Probability         0.17   0.000000e+00
# 5190  Topic_30_Probability   Topic_80_Probability         0.15   0.000000e+00
# 5228  Topic_31_Probability   Topic_49_Probability        -0.11  2.545524e-201
# 5241  Topic_31_Probability   Topic_62_Probability        -0.14   0.000000e+00
# 5246  Topic_31_Probability   Topic_67_Probability        -0.10  2.821906e-190
# 5257  Topic_31_Probability   Topic_78_Probability         0.13  3.597897e-288
# 5267  Topic_31_Probability   Topic_88_Probability         0.13  1.471514e-302
# 5279  Topic_31_Probability  Topic_100_Probability         0.18   0.000000e+00
# 5421  Topic_34_Probability   Topic_41_Probability         0.12  8.118740e-249
# 5448  Topic_34_Probability   Topic_68_Probability         0.18   0.000000e+00
# 5474  Topic_34_Probability   Topic_94_Probability         0.11  1.394073e-219
# 5475  Topic_34_Probability   Topic_95_Probability         0.17   0.000000e+00
# 5548  Topic_36_Probability   Topic_39_Probability         0.12  1.450879e-261
# 5611  Topic_37_Probability   Topic_39_Probability         0.13  1.613498e-290
# 5613  Topic_37_Probability   Topic_41_Probability         0.16   0.000000e+00
# 5771  Topic_39_Probability   Topic_76_Probability         0.14   0.000000e+00
# 5866  Topic_41_Probability   Topic_52_Probability         0.28   0.000000e+00
# 5917  Topic_42_Probability   Topic_45_Probability         0.12  8.549841e-258
# 6303  Topic_49_Probability   Topic_53_Probability        -0.10  1.450604e-198
# 6304  Topic_49_Probability   Topic_54_Probability        -0.11  3.512486e-227
# 6305  Topic_49_Probability   Topic_55_Probability         0.12  2.286788e-267
# 6307  Topic_49_Probability   Topic_57_Probability        -0.10  1.915941e-183
# 6310  Topic_49_Probability   Topic_60_Probability         0.32   0.000000e+00
# 6312  Topic_49_Probability   Topic_62_Probability        -0.23   0.000000e+00
# 6317  Topic_49_Probability   Topic_67_Probability        -0.12  3.347657e-267
# 6321  Topic_49_Probability   Topic_71_Probability        -0.14   0.000000e+00
# 6330  Topic_49_Probability   Topic_80_Probability         0.25   0.000000e+00
# 6338  Topic_49_Probability   Topic_88_Probability        -0.13  7.763748e-319
# 6341  Topic_49_Probability   Topic_91_Probability         0.14   0.000000e+00
# 6345  Topic_49_Probability   Topic_95_Probability        -0.14   0.000000e+00
# 6350  Topic_49_Probability  Topic_100_Probability        -0.14   0.000000e+00
# 6409  Topic_51_Probability   Topic_60_Probability         0.15   0.000000e+00
# 6411  Topic_51_Probability   Topic_62_Probability        -0.11  1.147768e-237
# 6428  Topic_51_Probability   Topic_79_Probability         0.21   0.000000e+00
# 6434  Topic_51_Probability   Topic_85_Probability         0.11  1.371447e-216
# 6498  Topic_53_Probability   Topic_54_Probability        -0.18   0.000000e+00
# 6504  Topic_53_Probability   Topic_60_Probability        -0.18   0.000000e+00
# 6506  Topic_53_Probability   Topic_62_Probability        -0.16   0.000000e+00
# 6507  Topic_53_Probability   Topic_63_Probability         0.27   0.000000e+00
# 6510  Topic_53_Probability   Topic_66_Probability         0.27   0.000000e+00
# 6532  Topic_53_Probability   Topic_88_Probability         0.41   0.000000e+00
# 6539  Topic_53_Probability   Topic_95_Probability         0.27   0.000000e+00
# 6544  Topic_53_Probability  Topic_100_Probability        -0.19   0.000000e+00
# 6548  Topic_54_Probability   Topic_58_Probability         0.27   0.000000e+00
# 6552  Topic_54_Probability   Topic_62_Probability        -0.16   0.000000e+00
# 6562  Topic_54_Probability   Topic_72_Probability         0.10  2.233529e-195
# 6569  Topic_54_Probability   Topic_79_Probability         0.11  3.720779e-223
# 6578  Topic_54_Probability   Topic_88_Probability        -0.20   0.000000e+00
# 6585  Topic_54_Probability   Topic_95_Probability        -0.12  2.636157e-245
# 6590  Topic_54_Probability  Topic_100_Probability        -0.16   0.000000e+00
# 6681  Topic_57_Probability   Topic_59_Probability         0.43   0.000000e+00
# 6682  Topic_57_Probability   Topic_60_Probability        -0.11  4.665872e-221
# 6710  Topic_57_Probability   Topic_88_Probability         0.21   0.000000e+00
# 6715  Topic_57_Probability   Topic_93_Probability         0.24   0.000000e+00
# 6724  Topic_58_Probability   Topic_60_Probability        -0.10  1.178615e-196
# 6765  Topic_59_Probability   Topic_60_Probability        -0.11  4.810215e-236
# 6793  Topic_59_Probability   Topic_88_Probability         0.40   0.000000e+00
# 6798  Topic_59_Probability   Topic_93_Probability         0.36   0.000000e+00
# 6805  Topic_59_Probability  Topic_100_Probability        -0.11  3.133760e-222
# 6807  Topic_60_Probability   Topic_62_Probability        -0.34   0.000000e+00
# 6812  Topic_60_Probability   Topic_67_Probability        -0.10  7.991215e-189
# 6824  Topic_60_Probability   Topic_79_Probability         0.22   0.000000e+00
# 6825  Topic_60_Probability   Topic_80_Probability         0.27   0.000000e+00
# 6833  Topic_60_Probability   Topic_88_Probability        -0.18   0.000000e+00
# 6845  Topic_60_Probability  Topic_100_Probability        -0.10  2.164290e-195
# 6885  Topic_62_Probability   Topic_63_Probability        -0.14   0.000000e+00
# 6888  Topic_62_Probability   Topic_66_Probability        -0.11  2.649590e-225
# 6892  Topic_62_Probability   Topic_70_Probability        -0.11  1.641164e-207
# 6901  Topic_62_Probability   Topic_79_Probability        -0.13  8.353395e-298
# 6910  Topic_62_Probability   Topic_88_Probability        -0.16   0.000000e+00
# 6917  Topic_62_Probability   Topic_95_Probability        -0.15   0.000000e+00
# 6922  Topic_62_Probability  Topic_100_Probability        -0.20   0.000000e+00
# 6925  Topic_63_Probability   Topic_66_Probability         0.27   0.000000e+00
# 6947  Topic_63_Probability   Topic_88_Probability         0.17   0.000000e+00
# 6959  Topic_63_Probability  Topic_100_Probability        -0.15   0.000000e+00
# 6975  Topic_64_Probability   Topic_80_Probability         0.27   0.000000e+00
# 7010  Topic_65_Probability   Topic_80_Probability         0.16   0.000000e+00
# 7052  Topic_66_Probability   Topic_88_Probability         0.14   0.000000e+00
# 7068  Topic_67_Probability   Topic_71_Probability        -0.11  1.778825e-220
# 7085  Topic_67_Probability   Topic_88_Probability        -0.21   0.000000e+00
# 7092  Topic_67_Probability   Topic_95_Probability        -0.16   0.000000e+00
# 7097  Topic_67_Probability  Topic_100_Probability        -0.19   0.000000e+00
# 7219  Topic_71_Probability  Topic_100_Probability         0.16   0.000000e+00
# 7250  Topic_73_Probability   Topic_76_Probability         0.17   0.000000e+00
# 7449  Topic_81_Probability   Topic_95_Probability         0.12  2.365876e-259
# 7500  Topic_84_Probability   Topic_95_Probability         0.11  1.734211e-238
# 7554  Topic_88_Probability   Topic_95_Probability         0.24   0.000000e+00
# 7559  Topic_88_Probability  Topic_100_Probability        -0.13  6.512773e-320
# 7615  Topic_95_Probability  Topic_100_Probability        -0.16   0.000000e+00
#
#                                                                                                 attr1_topic_words  \
# 0
# 1
# 2
# 3
# 5
# 6
# 8
# 10
# 12
# 31
# 53
# 82
# 84
# 117
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
#
# 7219                                                100: like, yeah, know, oh, right, got, okay, think, one, get
# 7250         76: subhanahu, screenings, fluoride, osceola, courier, platte, mutants, iot, mitigation, sallallahu
# 7449                                           95: back, could, sleep, around, one, head, body, feet, skin, eyes
# 7500                                           95: back, could, sleep, around, one, head, body, feet, skin, eyes
# 7554                                           95: back, could, sleep, around, one, head, body, feet, skin, eyes
# 7559                                                100: like, yeah, know, oh, right, got, okay, think, one, get
# 7615                                                100: like, yeah, know, oh, right, got, okay, think, one, get

# %%
get_results_df(only_one_episode_per_show=True)
# Out:
# df length: 15117
# Numeric columns: ['duration', 'transcript_length', 'parse_INTJ_count', 'parse_EDITED_count', 'parse_PRN_count', 'parse_ADJP_count', 'parse_ADVP_count', 'parse_NP_count', 'parse_PP_count', 'parse_S_count', 'parse_SBAR_count', 'parse_SBARQ_count', 'parse_SINV_count', 'parse_SQ_count', 'parse_VP_count', 'parse_WHADVP_count', 'parse_WHNP_count', 'parse_WHPP_count', 'parse_X_count', 'female', 'male', 'music', 'noEnergy', 'noise', 'Topic_1_Probability', 'Topic_2_Probability', 'Topic_3_Probability', 'Topic_4_Probability', 'Topic_5_Probability', 'Topic_6_Probability', 'Topic_7_Probability', 'Topic_8_Probability', 'Topic_9_Probability', 'Topic_10_Probability', 'Topic_11_Probability', 'Topic_12_Probability', 'Topic_13_Probability', 'Topic_14_Probability', 'Topic_15_Probability', 'Topic_16_Probability', 'Topic_17_Probability', 'Topic_18_Probability', 'Topic_19_Probability', 'Topic_20_Probability', 'Topic_21_Probability', 'Topic_22_Probability', 'Topic_23_Probability', 'Topic_24_Probability', 'Topic_25_Probability', 'Topic_26_Probability', 'Topic_27_Probability', 'Topic_28_Probability', 'Topic_29_Probability', 'Topic_30_Probability', 'Topic_31_Probability', 'Topic_32_Probability', 'Topic_33_Probability', 'Topic_34_Probability', 'Topic_35_Probability', 'Topic_36_Probability', 'Topic_37_Probability', 'Topic_38_Probability', 'Topic_39_Probability', 'Topic_40_Probability', 'Topic_41_Probability', 'Topic_42_Probability', 'Topic_43_Probability', 'Topic_44_Probability', 'Topic_45_Probability', 'Topic_46_Probability', 'Topic_47_Probability', 'Topic_48_Probability', 'Topic_49_Probability', 'Topic_50_Probability', 'Topic_51_Probability', 'Topic_52_Probability', 'Topic_53_Probability', 'Topic_54_Probability', 'Topic_55_Probability', 'Topic_56_Probability', 'Topic_57_Probability', 'Topic_58_Probability', 'Topic_59_Probability', 'Topic_60_Probability', 'Topic_61_Probability', 'Topic_62_Probability', 'Topic_63_Probability', 'Topic_64_Probability', 'Topic_65_Probability', 'Topic_66_Probability', 'Topic_67_Probability', 'Topic_68_Probability', 'Topic_69_Probability', 'Topic_70_Probability', 'Topic_71_Probability', 'Topic_72_Probability', 'Topic_73_Probability', 'Topic_74_Probability', 'Topic_75_Probability', 'Topic_76_Probability', 'Topic_77_Probability', 'Topic_78_Probability', 'Topic_79_Probability', 'Topic_80_Probability', 'Topic_81_Probability', 'Topic_82_Probability', 'Topic_83_Probability', 'Topic_84_Probability', 'Topic_85_Probability', 'Topic_86_Probability', 'Topic_87_Probability', 'Topic_88_Probability', 'Topic_89_Probability', 'Topic_90_Probability', 'Topic_91_Probability', 'Topic_92_Probability', 'Topic_93_Probability', 'Topic_94_Probability', 'Topic_95_Probability', 'Topic_96_Probability', 'Topic_97_Probability', 'Topic_98_Probability', 'Topic_99_Probability', 'Topic_100_Probability']
# # of numeric columns: 124
#
# number of tests run: 7626
# alpha_adjusted: 6.5565171780750066e-06
#                      attr1                  attr2  correlation         pvalue  \
# 0                 duration      transcript_length         0.16   2.294008e-83
# 1                 duration       parse_INTJ_count         0.30  8.736999e-311
# 2                 duration     parse_EDITED_count         0.26  3.137606e-234
# 3                 duration        parse_PRN_count         0.14   1.320171e-67
# 5                 duration       parse_ADVP_count         0.15   1.377742e-79
# 6                 duration         parse_NP_count         0.16   1.613653e-87
# 8                 duration          parse_S_count         0.11   2.645515e-45
# 10                duration      parse_SBARQ_count         0.10   3.366375e-35
# 12                duration         parse_SQ_count         0.16   8.495998e-83
# 18                duration                 female        -0.17   1.195670e-94
# 19                duration                   male         0.12   4.180851e-47
# 31                duration    Topic_9_Probability        -0.18  2.634400e-109
# 82                duration   Topic_60_Probability         0.13   1.598117e-61
# 84                duration   Topic_62_Probability        -0.22  4.663933e-164
# 117               duration   Topic_95_Probability        -0.11   1.795489e-42
# 122               duration  Topic_100_Probability         0.27  4.297457e-242
# 123      transcript_length       parse_INTJ_count         0.32   0.000000e+00
# 124      transcript_length     parse_EDITED_count         0.38   0.000000e+00
# 125      transcript_length        parse_PRN_count         0.31   0.000000e+00
# 126      transcript_length       parse_ADJP_count         0.48   0.000000e+00
# 127      transcript_length       parse_ADVP_count         0.68   0.000000e+00
# 128      transcript_length         parse_NP_count         0.94   0.000000e+00
# 129      transcript_length         parse_PP_count         0.59   0.000000e+00
# 130      transcript_length          parse_S_count         0.85   0.000000e+00
# 131      transcript_length       parse_SBAR_count         0.66   0.000000e+00
# 132      transcript_length      parse_SBARQ_count         0.20  1.200179e-131
# 134      transcript_length         parse_SQ_count         0.23  9.253093e-175
# 135      transcript_length         parse_VP_count         0.86   0.000000e+00
# 136      transcript_length     parse_WHADVP_count         0.39   0.000000e+00
# 137      transcript_length       parse_WHNP_count         0.39   0.000000e+00
# 141      transcript_length                   male         0.15   2.264055e-77
# 143      transcript_length               noEnergy        -0.12   2.395592e-47
# 144      transcript_length                  noise        -0.12   2.981722e-53
# 146      transcript_length    Topic_2_Probability        -0.12   2.413248e-49
# 153      transcript_length    Topic_9_Probability        -0.21  6.522374e-148
# 154      transcript_length   Topic_10_Probability        -0.29  2.286016e-283
# 155      transcript_length   Topic_11_Probability        -0.10   3.952633e-37
# 193      transcript_length   Topic_49_Probability         0.12   2.568384e-50
# 197      transcript_length   Topic_53_Probability        -0.15   9.677016e-81
# 202      transcript_length   Topic_58_Probability        -0.12   2.599387e-50
# 204      transcript_length   Topic_60_Probability         0.15   7.436469e-74
# 207      transcript_length   Topic_63_Probability        -0.13   1.447551e-56
# 211      transcript_length   Topic_67_Probability         0.10   1.620064e-35
# 232      transcript_length   Topic_88_Probability        -0.19  5.483719e-129
# 239      transcript_length   Topic_95_Probability        -0.29  1.018979e-281
# 244      transcript_length  Topic_100_Probability         0.14   1.487160e-69
# 245       parse_INTJ_count     parse_EDITED_count         0.44   0.000000e+00
# 246       parse_INTJ_count        parse_PRN_count         0.21  1.182318e-149
# 247       parse_INTJ_count       parse_ADJP_count         0.26  7.477536e-226
# 248       parse_INTJ_count       parse_ADVP_count         0.36   0.000000e+00
# 249       parse_INTJ_count         parse_NP_count         0.27  1.850421e-259
# 250       parse_INTJ_count         parse_PP_count        -0.28  9.296898e-272
# 251       parse_INTJ_count          parse_S_count         0.32   0.000000e+00
# 253       parse_INTJ_count      parse_SBARQ_count         0.35   0.000000e+00
# 255       parse_INTJ_count         parse_SQ_count         0.44   0.000000e+00
# 256       parse_INTJ_count         parse_VP_count         0.28  2.530630e-262
# 259       parse_INTJ_count       parse_WHPP_count        -0.14   1.895258e-71
# 274       parse_INTJ_count    Topic_9_Probability        -0.39   0.000000e+00
# 275       parse_INTJ_count   Topic_10_Probability        -0.16   4.409356e-89
# 276       parse_INTJ_count   Topic_11_Probability        -0.21  3.325293e-148
# 277       parse_INTJ_count   Topic_12_Probability        -0.16   5.304506e-83
# 299       parse_INTJ_count   Topic_34_Probability        -0.11   8.097079e-42
# 314       parse_INTJ_count   Topic_49_Probability        -0.11   1.254001e-42
# 318       parse_INTJ_count   Topic_53_Probability        -0.20  8.784866e-142
# 319       parse_INTJ_count   Topic_54_Probability        -0.13   4.041881e-58
# 324       parse_INTJ_count   Topic_59_Probability        -0.12   1.909356e-47
# 327       parse_INTJ_count   Topic_62_Probability        -0.21  3.171253e-154
# 328       parse_INTJ_count   Topic_63_Probability        -0.15   3.030735e-78
# 332       parse_INTJ_count   Topic_67_Probability        -0.15   1.278828e-75
# 336       parse_INTJ_count   Topic_71_Probability         0.10   6.783778e-36
# 353       parse_INTJ_count   Topic_88_Probability        -0.20  7.239963e-136
# 360       parse_INTJ_count   Topic_95_Probability        -0.19  2.295985e-122
# 365       parse_INTJ_count  Topic_100_Probability         0.86   0.000000e+00
# 366     parse_EDITED_count        parse_PRN_count         0.45   0.000000e+00
# 367     parse_EDITED_count       parse_ADJP_count         0.14   5.346876e-68
# 368     parse_EDITED_count       parse_ADVP_count         0.36   0.000000e+00
# 369     parse_EDITED_count         parse_NP_count         0.36   0.000000e+00
# 371     parse_EDITED_count          parse_S_count         0.38   0.000000e+00
# 372     parse_EDITED_count       parse_SBAR_count         0.19  2.678441e-129
# 373     parse_EDITED_count      parse_SBARQ_count         0.15   2.483119e-75
# 375     parse_EDITED_count         parse_SQ_count         0.16   9.029407e-86
# 376     parse_EDITED_count         parse_VP_count         0.37   0.000000e+00
# 377     parse_EDITED_count     parse_WHADVP_count         0.16   1.630103e-85
# 378     parse_EDITED_count       parse_WHNP_count         0.12   4.132057e-47
# 379     parse_EDITED_count       parse_WHPP_count        -0.11   8.894523e-44
# 381     parse_EDITED_count                 female        -0.14   2.332377e-70
# 382     parse_EDITED_count                   male         0.16   1.826142e-87
# 394     parse_EDITED_count    Topic_9_Probability        -0.27  3.465384e-259
# 395     parse_EDITED_count   Topic_10_Probability        -0.13   1.071251e-59
# 396     parse_EDITED_count   Topic_11_Probability        -0.17  3.813046e-102
# 438     parse_EDITED_count   Topic_53_Probability        -0.20  1.347438e-139
# 448     parse_EDITED_count   Topic_63_Probability        -0.12   2.546398e-53
# 473     parse_EDITED_count   Topic_88_Probability        -0.22  7.383477e-158
# 480     parse_EDITED_count   Topic_95_Probability        -0.22  6.220521e-169
# 485     parse_EDITED_count  Topic_100_Probability         0.37   0.000000e+00
# 486        parse_PRN_count       parse_ADJP_count         0.10   1.024033e-35
# 487        parse_PRN_count       parse_ADVP_count         0.34   0.000000e+00
# 488        parse_PRN_count         parse_NP_count         0.33   0.000000e+00
# 490        parse_PRN_count          parse_S_count         0.35   0.000000e+00
# 491        parse_PRN_count       parse_SBAR_count         0.19  4.334275e-127
# 495        parse_PRN_count         parse_VP_count         0.32   0.000000e+00
# 496        parse_PRN_count     parse_WHADVP_count         0.14   1.011218e-62
# 497        parse_PRN_count       parse_WHNP_count         0.16   6.123624e-83
# 500        parse_PRN_count                 female        -0.11   9.385047e-39
# 501        parse_PRN_count                   male         0.12   3.529210e-48
# 513        parse_PRN_count    Topic_9_Probability        -0.21  2.033396e-157
# 514        parse_PRN_count   Topic_10_Probability        -0.11   2.752033e-45
# 515        parse_PRN_count   Topic_11_Probability        -0.13   5.117890e-60
# 553        parse_PRN_count   Topic_49_Probability         0.13   9.708389e-61
# 557        parse_PRN_count   Topic_53_Probability        -0.17  1.337062e-101
# 592        parse_PRN_count   Topic_88_Probability        -0.22  3.655580e-171
# 599        parse_PRN_count   Topic_95_Probability        -0.22  6.492699e-159
# 604        parse_PRN_count  Topic_100_Probability         0.17   1.075766e-95
# 605       parse_ADJP_count       parse_ADVP_count         0.37   0.000000e+00
# 606       parse_ADJP_count         parse_NP_count         0.39   0.000000e+00
# 607       parse_ADJP_count         parse_PP_count         0.13   5.261274e-60
# 608       parse_ADJP_count          parse_S_count         0.50   0.000000e+00
# 609       parse_ADJP_count       parse_SBAR_count         0.38   0.000000e+00
# 610       parse_ADJP_count      parse_SBARQ_count         0.10   2.747895e-37
# 612       parse_ADJP_count         parse_SQ_count         0.15   3.576714e-80
# 613       parse_ADJP_count         parse_VP_count         0.47   0.000000e+00
# 614       parse_ADJP_count     parse_WHADVP_count         0.18  1.072840e-113
# 615       parse_ADJP_count       parse_WHNP_count         0.13   7.301922e-62
# 618       parse_ADJP_count                 female         0.13   4.838421e-55
# 631       parse_ADJP_count    Topic_9_Probability        -0.10   2.104593e-37
# 632       parse_ADJP_count   Topic_10_Probability        -0.12   2.918726e-49
# 633       parse_ADJP_count   Topic_11_Probability        -0.14   2.432835e-68
# 675       parse_ADJP_count   Topic_53_Probability        -0.13   7.123700e-58
# 676       parse_ADJP_count   Topic_54_Probability        -0.12   1.973085e-51
# 681       parse_ADJP_count   Topic_59_Probability        -0.13   9.501373e-61
# 684       parse_ADJP_count   Topic_62_Probability         0.19  6.501899e-120
# 685       parse_ADJP_count   Topic_63_Probability        -0.13   2.131078e-60
# 710       parse_ADJP_count   Topic_88_Probability        -0.19  3.357672e-117
# 717       parse_ADJP_count   Topic_95_Probability        -0.13   6.374390e-60
# 722       parse_ADJP_count  Topic_100_Probability         0.17   3.317758e-94
# 723       parse_ADVP_count         parse_NP_count         0.60   0.000000e+00
# 724       parse_ADVP_count         parse_PP_count         0.28  7.498437e-271
# 725       parse_ADVP_count          parse_S_count         0.56   0.000000e+00
# 726       parse_ADVP_count       parse_SBAR_count         0.41   0.000000e+00
# 729       parse_ADVP_count         parse_SQ_count         0.11   2.528288e-40
# 730       parse_ADVP_count         parse_VP_count         0.58   0.000000e+00
# 731       parse_ADVP_count     parse_WHADVP_count         0.28  8.516057e-264
# 732       parse_ADVP_count       parse_WHNP_count         0.22  3.805917e-170
# 733       parse_ADVP_count       parse_WHPP_count        -0.13   1.284780e-59
# 741       parse_ADVP_count    Topic_2_Probability        -0.11   1.843585e-39
# 748       parse_ADVP_count    Topic_9_Probability        -0.29  1.739827e-294
# 749       parse_ADVP_count   Topic_10_Probability        -0.18  2.624047e-111
# 750       parse_ADVP_count   Topic_11_Probability        -0.21  3.266995e-147
# 773       parse_ADVP_count   Topic_34_Probability        -0.10   7.597750e-38
# 792       parse_ADVP_count   Topic_53_Probability        -0.21  1.223376e-148
# 798       parse_ADVP_count   Topic_59_Probability        -0.17   6.554015e-99
# 799       parse_ADVP_count   Topic_60_Probability         0.19  3.298531e-127
# 802       parse_ADVP_count   Topic_63_Probability        -0.20  5.012109e-131
# 806       parse_ADVP_count   Topic_67_Probability         0.11   1.237346e-42
# 827       parse_ADVP_count   Topic_88_Probability        -0.30  2.514010e-305
# 834       parse_ADVP_count   Topic_95_Probability        -0.23  4.907527e-173
# 839       parse_ADVP_count  Topic_100_Probability         0.22  4.709019e-169
# 840         parse_NP_count         parse_PP_count         0.58   0.000000e+00
# 841         parse_NP_count          parse_S_count         0.77   0.000000e+00
# 842         parse_NP_count       parse_SBAR_count         0.59   0.000000e+00
# 843         parse_NP_count      parse_SBARQ_count         0.17   8.814468e-97
# 845         parse_NP_count         parse_SQ_count         0.20  6.227904e-142
# 846         parse_NP_count         parse_VP_count         0.78   0.000000e+00
# 847         parse_NP_count     parse_WHADVP_count         0.35   0.000000e+00
# 848         parse_NP_count       parse_WHNP_count         0.42   0.000000e+00
# 852         parse_NP_count                   male         0.17   1.375858e-98
# 854         parse_NP_count               noEnergy        -0.12   5.602575e-49
# 855         parse_NP_count                  noise        -0.11   1.087420e-42
# 857         parse_NP_count    Topic_2_Probability        -0.11   6.940498e-39
# 864         parse_NP_count    Topic_9_Probability        -0.19  8.851205e-128
# 865         parse_NP_count   Topic_10_Probability        -0.29  6.264442e-292
# 904         parse_NP_count   Topic_49_Probability         0.11   3.334623e-43
# 908         parse_NP_count   Topic_53_Probability        -0.13   1.220969e-54
# 913         parse_NP_count   Topic_58_Probability        -0.11   1.078372e-43
# 915         parse_NP_count   Topic_60_Probability         0.11   6.413471e-44
# 943         parse_NP_count   Topic_88_Probability        -0.12   1.959974e-51
# 950         parse_NP_count   Topic_95_Probability        -0.29  7.424692e-283
# 955         parse_NP_count  Topic_100_Probability         0.14   1.067325e-64
# 956         parse_PP_count          parse_S_count         0.31   0.000000e+00
# 957         parse_PP_count       parse_SBAR_count         0.40   0.000000e+00
# 960         parse_PP_count         parse_SQ_count        -0.12   1.415410e-51
# 961         parse_PP_count         parse_VP_count         0.34   0.000000e+00
# 962         parse_PP_count     parse_WHADVP_count         0.23  3.680866e-180
# 963         parse_PP_count       parse_WHNP_count         0.29  2.029606e-296
# 964         parse_PP_count       parse_WHPP_count         0.11   1.702946e-38
# 966         parse_PP_count                 female        -0.10   4.943926e-36
# 967         parse_PP_count                   male         0.14   1.829483e-69
# 969         parse_PP_count               noEnergy        -0.12   1.003797e-46
# 979         parse_PP_count    Topic_9_Probability         0.17   2.300780e-96
# 980         parse_PP_count   Topic_10_Probability        -0.13   1.287485e-56
# 981         parse_PP_count   Topic_11_Probability         0.18  2.321405e-115
# 982         parse_PP_count   Topic_12_Probability         0.15   2.838304e-77
# 1019        parse_PP_count   Topic_49_Probability         0.11   1.193798e-39
# 1030        parse_PP_count   Topic_60_Probability         0.16   6.374898e-88
# 1033        parse_PP_count   Topic_63_Probability         0.13   4.988219e-56
# 1037        parse_PP_count   Topic_67_Probability         0.35   0.000000e+00
# 1041        parse_PP_count   Topic_71_Probability        -0.15   1.659464e-73
# 1070        parse_PP_count  Topic_100_Probability        -0.43   0.000000e+00
# 1071         parse_S_count       parse_SBAR_count         0.84   0.000000e+00
# 1072         parse_S_count      parse_SBARQ_count         0.29  2.609938e-282
# 1074         parse_S_count         parse_SQ_count         0.30  1.047092e-305
# 1075         parse_S_count         parse_VP_count         0.94   0.000000e+00
# 1076         parse_S_count     parse_WHADVP_count         0.50   0.000000e+00
# 1077         parse_S_count       parse_WHNP_count         0.47   0.000000e+00
# 1078         parse_S_count       parse_WHPP_count        -0.10   4.453262e-36
# 1084         parse_S_count                  noise        -0.11   1.552857e-41
# 1093         parse_S_count    Topic_9_Probability        -0.20  3.187866e-141
# 1094         parse_S_count   Topic_10_Probability        -0.23  1.972072e-178
# 1095         parse_S_count   Topic_11_Probability        -0.22  7.466664e-161
# 1118         parse_S_count   Topic_34_Probability        -0.12   8.723948e-46
# 1137         parse_S_count   Topic_53_Probability        -0.23  2.852648e-186
# 1146         parse_S_count   Topic_62_Probability         0.26  7.348583e-232
# 1147         parse_S_count   Topic_63_Probability        -0.20  1.195923e-139
# 1172         parse_S_count   Topic_88_Probability        -0.18  1.840491e-114
# 1179         parse_S_count   Topic_95_Probability        -0.33   0.000000e+00
# 1184         parse_S_count  Topic_100_Probability         0.19  8.569621e-123
# 1185      parse_SBAR_count      parse_SBARQ_count         0.19  2.318883e-123
# 1187      parse_SBAR_count         parse_SQ_count         0.14   7.385819e-64
# 1188      parse_SBAR_count         parse_VP_count         0.72   0.000000e+00
# 1189      parse_SBAR_count     parse_WHADVP_count         0.57   0.000000e+00
# 1190      parse_SBAR_count       parse_WHNP_count         0.61   0.000000e+00
# 1197      parse_SBAR_count                  noise        -0.11   1.390931e-39
# 1207      parse_SBAR_count   Topic_10_Probability        -0.15   1.172289e-81
# 1208      parse_SBAR_count   Topic_11_Probability        -0.10   5.012347e-35
# 1250      parse_SBAR_count   Topic_53_Probability        -0.20  4.406420e-134
# 1259      parse_SBAR_count   Topic_62_Probability         0.38   0.000000e+00
# 1260      parse_SBAR_count   Topic_63_Probability        -0.11   7.039058e-41
# 1268      parse_SBAR_count   Topic_71_Probability        -0.12   8.717534e-51
# 1285      parse_SBAR_count   Topic_88_Probability        -0.14   6.492711e-67
# 1292      parse_SBAR_count   Topic_95_Probability        -0.29  1.990714e-284
# 1297      parse_SBAR_count  Topic_100_Probability        -0.11   7.948182e-43
# 1299     parse_SBARQ_count         parse_SQ_count         0.82   0.000000e+00
# 1300     parse_SBARQ_count         parse_VP_count         0.19  2.037975e-118
# 1301     parse_SBARQ_count     parse_WHADVP_count         0.29  2.406263e-284
# 1302     parse_SBARQ_count       parse_WHNP_count         0.24  9.365969e-205
# 1306     parse_SBARQ_count                   male         0.11   1.071624e-40
# 1318     parse_SBARQ_count    Topic_9_Probability        -0.13   5.089883e-62
# 1362     parse_SBARQ_count   Topic_53_Probability        -0.16   8.895527e-84
# 1404     parse_SBARQ_count   Topic_95_Probability        -0.15   1.779863e-75
# 1409     parse_SBARQ_count  Topic_100_Probability         0.30  3.796430e-302
# 1508      parse_SINV_count   Topic_88_Probability         0.13   5.727892e-56
# 1521        parse_SQ_count         parse_VP_count         0.20  1.074372e-139
# 1522        parse_SQ_count     parse_WHADVP_count         0.20  5.283912e-140
# 1523        parse_SQ_count       parse_WHNP_count         0.15   1.787033e-80
# 1527        parse_SQ_count                   male         0.10   4.056263e-35
# 1539        parse_SQ_count    Topic_9_Probability        -0.19  2.483042e-123
# 1540        parse_SQ_count   Topic_10_Probability        -0.12   8.072035e-50
# 1541        parse_SQ_count   Topic_11_Probability        -0.10   4.688337e-37
# 1560        parse_SQ_count   Topic_30_Probability         0.12   9.917657e-50
# 1583        parse_SQ_count   Topic_53_Probability        -0.15   7.076223e-79
# 1592        parse_SQ_count   Topic_62_Probability        -0.15   7.359356e-78
# 1625        parse_SQ_count   Topic_95_Probability        -0.13   2.166583e-61
# 1630        parse_SQ_count  Topic_100_Probability         0.38   0.000000e+00
# 1631        parse_VP_count     parse_WHADVP_count         0.40   0.000000e+00
# 1632        parse_VP_count       parse_WHNP_count         0.40   0.000000e+00
# 1633        parse_VP_count       parse_WHPP_count        -0.11   3.473197e-43
# 1637        parse_VP_count                  music        -0.10   1.101313e-35
# 1639        parse_VP_count                  noise        -0.11   1.479507e-42
# 1641        parse_VP_count    Topic_2_Probability        -0.11   2.115052e-40
# 1648        parse_VP_count    Topic_9_Probability        -0.22  1.674619e-162
# 1649        parse_VP_count   Topic_10_Probability        -0.22  1.301352e-167
# 1650        parse_VP_count   Topic_11_Probability        -0.22  3.945552e-164
# 1673        parse_VP_count   Topic_34_Probability        -0.11   9.607150e-44
# 1692        parse_VP_count   Topic_53_Probability        -0.22  2.265128e-163
# 1696        parse_VP_count   Topic_57_Probability        -0.11   2.320309e-44
# 1701        parse_VP_count   Topic_62_Probability         0.24  1.547488e-200
# 1702        parse_VP_count   Topic_63_Probability        -0.22  1.945269e-164
# 1727        parse_VP_count   Topic_88_Probability        -0.18  3.999751e-114
# 1734        parse_VP_count   Topic_95_Probability        -0.30  1.858250e-302
# 1739        parse_VP_count  Topic_100_Probability         0.17   5.158406e-93
# 1740    parse_WHADVP_count       parse_WHNP_count         0.28  1.501369e-268
# 1796    parse_WHADVP_count   Topic_49_Probability        -0.13   1.045446e-57
# 1800    parse_WHADVP_count   Topic_53_Probability        -0.11   3.016850e-42
# 1805    parse_WHADVP_count   Topic_58_Probability        -0.10   9.100009e-36
# 1807    parse_WHADVP_count   Topic_60_Probability        -0.15   5.708393e-72
# 1809    parse_WHADVP_count   Topic_62_Probability         0.29  4.611698e-296
# 1814    parse_WHADVP_count   Topic_67_Probability         0.18  3.087160e-107
# 1835    parse_WHADVP_count   Topic_88_Probability        -0.13   2.646490e-60
# 1842    parse_WHADVP_count   Topic_95_Probability        -0.18  1.319080e-106
# 1863      parse_WHNP_count    Topic_9_Probability         0.11   1.513768e-45
# 1907      parse_WHNP_count   Topic_53_Probability        -0.18  8.224338e-111
# 1914      parse_WHNP_count   Topic_60_Probability        -0.11   1.645491e-41
# 1916      parse_WHNP_count   Topic_62_Probability         0.24  8.670433e-202
# 1921      parse_WHNP_count   Topic_67_Probability         0.12   1.741044e-47
# 1925      parse_WHNP_count   Topic_71_Probability        -0.11   1.465488e-42
# 1942      parse_WHNP_count   Topic_88_Probability        -0.11   1.389663e-39
# 1949      parse_WHNP_count   Topic_95_Probability        -0.23  6.716025e-180
# 1969      parse_WHPP_count    Topic_9_Probability         0.19  3.436359e-125
# 1971      parse_WHPP_count   Topic_11_Probability         0.14   4.736822e-63
# 2013      parse_WHPP_count   Topic_53_Probability         0.11   5.094978e-39
# 2023      parse_WHPP_count   Topic_63_Probability         0.14   2.201342e-65
# 2048      parse_WHPP_count   Topic_88_Probability         0.14   4.666067e-65
# 2060      parse_WHPP_count  Topic_100_Probability        -0.15   3.658125e-73
# 2166                female                   male        -0.76   0.000000e+00
# 2167                female                  music        -0.22  4.712608e-163
# 2172                female    Topic_3_Probability         0.15   4.087243e-73
# 2179                female   Topic_10_Probability         0.10   2.763567e-37
# 2218                female   Topic_49_Probability        -0.21  2.087149e-153
# 2229                female   Topic_60_Probability        -0.27  1.302373e-254
# 5474  Topic_34_Probability   Topic_94_Probability         0.12   8.900098e-47
# 5475  Topic_34_Probability   Topic_95_Probability         0.20  7.298324e-134
# 5480  Topic_34_Probability  Topic_100_Probability        -0.11   9.998124e-40
# 5548  Topic_36_Probability   Topic_39_Probability         0.11   1.967405e-44
# 5603  Topic_36_Probability   Topic_94_Probability         0.11   2.754300e-43
# 5613  Topic_37_Probability   Topic_41_Probability         0.23  3.259941e-178
# 5866  Topic_41_Probability   Topic_52_Probability         0.45   0.000000e+00
# 6173  Topic_46_Probability   Topic_79_Probability         0.11   2.703851e-43
# 6296  Topic_48_Probability   Topic_97_Probability         0.15   5.695037e-72
# 6304  Topic_49_Probability   Topic_54_Probability        -0.10   3.934205e-35
# 6307  Topic_49_Probability   Topic_57_Probability        -0.11   2.368674e-39
# 6310  Topic_49_Probability   Topic_60_Probability         0.27  2.971157e-252
# 6312  Topic_49_Probability   Topic_62_Probability        -0.23  7.468583e-185
# 6317  Topic_49_Probability   Topic_67_Probability        -0.12   1.446243e-46
# 6321  Topic_49_Probability   Topic_71_Probability        -0.13   8.608724e-61
# 6330  Topic_49_Probability   Topic_80_Probability         0.21  4.763890e-151
# 6338  Topic_49_Probability   Topic_88_Probability        -0.12   1.042949e-47
# 6341  Topic_49_Probability   Topic_91_Probability         0.11   1.028660e-39
# 6345  Topic_49_Probability   Topic_95_Probability        -0.13   2.796164e-55
# 6350  Topic_49_Probability  Topic_100_Probability        -0.14   1.294513e-71
# 6409  Topic_51_Probability   Topic_60_Probability         0.11   1.093999e-39
# 6411  Topic_51_Probability   Topic_62_Probability        -0.12   5.006511e-49
# 6428  Topic_51_Probability   Topic_79_Probability         0.20  1.330284e-139
# 6434  Topic_51_Probability   Topic_85_Probability         0.18  3.471855e-105
# 6498  Topic_53_Probability   Topic_54_Probability        -0.13   1.664026e-59
# 6504  Topic_53_Probability   Topic_60_Probability        -0.11   3.941909e-42
# 6507  Topic_53_Probability   Topic_63_Probability         0.20  3.986185e-137
# 6510  Topic_53_Probability   Topic_66_Probability         0.17   3.223636e-93
# 6532  Topic_53_Probability   Topic_88_Probability         0.37   0.000000e+00
# 6539  Topic_53_Probability   Topic_95_Probability         0.19  6.337221e-122
# 6544  Topic_53_Probability  Topic_100_Probability        -0.15   8.681784e-73
# 6548  Topic_54_Probability   Topic_58_Probability         0.31   0.000000e+00
# 6552  Topic_54_Probability   Topic_62_Probability        -0.16   9.928531e-87
# 6578  Topic_54_Probability   Topic_88_Probability        -0.15   8.948124e-77
# 6590  Topic_54_Probability  Topic_100_Probability        -0.14   8.407004e-66
# 6681  Topic_57_Probability   Topic_59_Probability         0.33   0.000000e+00
# 6710  Topic_57_Probability   Topic_88_Probability         0.19  6.852103e-124
# 6731  Topic_58_Probability   Topic_67_Probability        -0.10   9.797033e-36
# 6765  Topic_59_Probability   Topic_60_Probability        -0.11   8.994331e-42
# 6793  Topic_59_Probability   Topic_88_Probability         0.42   0.000000e+00
# 6798  Topic_59_Probability   Topic_93_Probability         0.11   3.243467e-44
# 6805  Topic_59_Probability  Topic_100_Probability        -0.13   1.190650e-55
# 6807  Topic_60_Probability   Topic_62_Probability        -0.34   0.000000e+00
# 6824  Topic_60_Probability   Topic_79_Probability         0.18  2.136497e-111
# 6825  Topic_60_Probability   Topic_80_Probability         0.23  1.505026e-180
# 6833  Topic_60_Probability   Topic_88_Probability        -0.12   7.880912e-46
# 6845  Topic_60_Probability  Topic_100_Probability        -0.13   2.931408e-56
# 6885  Topic_62_Probability   Topic_63_Probability        -0.12   9.790777e-53
# 6892  Topic_62_Probability   Topic_70_Probability        -0.10   1.102199e-36
# 6901  Topic_62_Probability   Topic_79_Probability        -0.13   3.353480e-58
# 6910  Topic_62_Probability   Topic_88_Probability        -0.15   1.684793e-75
# 6917  Topic_62_Probability   Topic_95_Probability        -0.11   1.127131e-44
# 6922  Topic_62_Probability  Topic_100_Probability        -0.29  3.603409e-300
# 6925  Topic_63_Probability   Topic_66_Probability         0.26  1.003011e-227
# 6947  Topic_63_Probability   Topic_88_Probability         0.13   4.927950e-56
# 6959  Topic_63_Probability  Topic_100_Probability        -0.14   3.456478e-66
# 6975  Topic_64_Probability   Topic_80_Probability         0.22  6.173875e-169
# 7010  Topic_65_Probability   Topic_80_Probability         0.12   9.415247e-50
# 7068  Topic_67_Probability   Topic_71_Probability        -0.12   6.868281e-53
# 7085  Topic_67_Probability   Topic_88_Probability        -0.20  3.158708e-138
# 7092  Topic_67_Probability   Topic_95_Probability        -0.15   5.324610e-80
# 7097  Topic_67_Probability  Topic_100_Probability        -0.30  1.864140e-313
# 7219  Topic_71_Probability  Topic_100_Probability         0.18  2.067692e-110
# 7250  Topic_73_Probability   Topic_76_Probability         0.25  7.958863e-208
# 7532  Topic_86_Probability   Topic_98_Probability         0.24  2.669834e-198
# 7554  Topic_88_Probability   Topic_95_Probability         0.20  1.117963e-142
# 7559  Topic_88_Probability  Topic_100_Probability        -0.12   6.873784e-50
# 7615  Topic_95_Probability  Topic_100_Probability        -0.13   3.405107e-57
#
#                                                                                                 attr1_topic_words  \
# 0
# 1
# 2
# 3
# 5
# 6
# 8
# 10
# 12
# 18
# 19
# 31
# 82
# 84
# 117
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 134
# 135
# 136
# 137
# 141
# 143
# 144
# 146
# 153
# 154
# 155
# 193
# 197
# 202
# 204
# 207
# 211
# 232
# 239
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 253
# 255
# 256
# 259
# 274
# 275
# 276
# 277
# 299
# 314
# 318
# 319
# 324
# 327
# 328
# 332
# 336
# 353
# ...
# 2768            94: fireheart, pulmonary, graystripe, trello, geriatric, bluestar, comminuted, sparing, ota, fuses
# 2903                           34: patients, pain, patient, disease, treatment, injury, risk, test, type, symptoms
# 2931                                         62: like, know, really, going, people, want, think, get, things, life
# 3005                     40: parade, packet, ajax, snoop, strand, packets, leveraged, enrichment, ungrateful, mech
# 3087                                27: matt, jewish, keys, wallet, block, freaks, rebbe, cash, mitzvah, unchained
# 3113                                    53: would, family, years, could, children, father, life, time, home, young
# 3148                                                       88: one, said, would, man, see, way, says, let, say, us
