# %% [markdown]
# # get_whisperx_googleasr_table.ipynb
#
# This notebook:
# * Gets the comparison of WhisperX and Google ASR.

# %%
import pandas as pd
import os
import json
import string
import re

from urlextract import URLExtract

import utils_general

def clean_urls(text):
    extractor = URLExtract()
    urls = extractor.find_urls(text)
    for url in urls:
        text = text.replace(url, "")
    return text

# modified from https://github.com/potsawee/podcast_trec2020/blob/main/data/processor.py
# also performs some basic cleaning
def get_transcript_text_from_json_asr_file(json_asr_file):
    transcript_list = []
    with open(json_asr_file) as f:
        transcript_dict = json.loads(f.read())
        
        results_list = [r for r in transcript_dict["results"]]
        last_result = results_list[-1]
        
        for word_dict in last_result["alternatives"][0]["words"]:
            endTime = float(word_dict["endTime"].replace("s",""))
            if endTime <= (60 * 10):  # 10 minutes
                transcript_list.append(word_dict["word"])
        
        transcript_string = " ".join(transcript_list)
        
        # clean the transcripts the same way as the descriptions
        transcript_string = clean_urls(transcript_string)
        transcript_string = transcript_string.encode("ascii", "ignore").decode()
        
        if transcript_string[-1] not in string.punctuation:
            transcript_string += "."
        
        return transcript_string


df = pd.read_csv("./csv/df.csv")

# set cols up for whisperx vs googleasr transcript comparison
df["transcript"] = df["transcript"].fillna("")
df = df.rename(columns={"transcript": "transcript_whisperx"})
df["transcript_googleasr"] = ""

result = pd.DataFrame()

display(df)

for i in range(5):
    # sample 100 at a time
    sampled_df_i = df.sample(n=100, random_state=i)

    for index, row in sampled_df_i.iterrows():
        # for those 100 files, retrieve the Google ASR transcription and write it into the df
        show_filename_prefix = row["show_filename_prefix"]
        episode_filename_prefix = row["episode_filename_prefix"]
        dir1 = show_filename_prefix.split("_")[1][0].upper()
        dir2 = show_filename_prefix.split("_")[1][1].upper()
        json_asr_file = os.path.join("/data2/maria/Spotify-Podcasts/podcasts-no-audio-13GB/spotify-podcasts-2020/podcasts-transcripts", dir1, dir2, show_filename_prefix, episode_filename_prefix+".json")

        sampled_df_i.loc[index,"transcript_googleasr"] = get_transcript_text_from_json_asr_file(json_asr_file)

    # calculate number of words in transcripts
    sampled_df_i["transcript_googleasr_length"] = -1
    for index, row in sampled_df_i.iterrows():
        # handle special case of empty string
        if row["transcript_googleasr"] != "":
            num_words = len(row["transcript_googleasr"].split(" "))
        else:
            num_words = 0
        # write in the number of words
        sampled_df_i.loc[index, "transcript_googleasr_length"] = num_words

    for target_str in ["uh", "um", "well"]:
        for asr_str in ["whisperx", "googleasr"]:
            sampled_df_i[f"{target_str}_count_{asr_str}"] = sampled_df_i[f"transcript_{asr_str}"].str.count(r"\b"+re.escape(target_str)+r"\b", flags=re.IGNORECASE)
            
    result = pd.concat([result, sampled_df_i], ignore_index=True)
    
display(result)
display(result.describe().round(2))
# Out:
#        Unnamed: 0                             show_uri  \
# 0               0  spotify:show:2NYtxEZyYelR6RMKmjfPLB
# 1               2  spotify:show:6vZRgUFTYwbAA79UNCADr4
# 2               3  spotify:show:5BvKEjaMSuvUsGROGi2S7s
# 3               4  spotify:show:7w3h3umpH74veEJcbE6xf4
# 4               5  spotify:show:5ljREb8VLogQLT7AKGwav1
# ...           ...                                  ...
# 82596      105355  spotify:show:416U8ZhubKrFHq8ynOaxfH
# 82597      105356  spotify:show:5rgmBAzsJ5znpV2b4WNDsb
# 82598      105357  spotify:show:56CjYLQWyMx1MkOEQmlubi
# 82599      105358  spotify:show:7uddSH8MhaK3Q6YFlllbVZ
# 82600      105359  spotify:show:6r0bfT6lOLqDMh9ujnT1BW
#
#                                                show_name  \
# 0                                   Kream in your Koffee
# 1      Inside The 18 : A Podcast for Goalkeepers by G...
# 2                                        Arrowhead Live!
# 3                                                  FBoL
# 4                                          UPSC Podcasts
# ...                                                  ...
# 82596                                         The Top 10
# 82597                          Let's Grab Coffee Podcast
# 82598                                  Coach Corey Wayne
# 82599                                The Cricket Podcast
# 82600           Sleepyhead Stories - Mother/Daughter Duo
#
#                                         show_description  \
# 0      A 20-something blunt female takes on the world...
# 1      Inside the 18 is your source for all things Go...
# 2      Your favorite podcast for everything @Chiefs! ...
# 3      The comedy podcast about toxic characters, wri...
# 4      Podcasts useful for UPSC aspirants! Mainly dis...
# ...                                                  ...
# 82596  Each week, John Rocha and Matt Knost breakdown...
# 82597  After connecting with someone, what's the next...
# 82598  Life & Peak Performance Coach. I Teach Self-Re...
# 82599  The best & funniest independent cricket podcas...
# 82600  Join this Mother-Daughter team for their weekl...
#
#                     publisher  \
# 0                 Katie Houle
# 1      Inside the 18 GK Media
# 2             Arrowhead Live!
# 3               Emily Edwards
# 4                UPSC Podcast
# ...                       ...
# 82596              The Top 10
# 82597          George Khalife
# 82598       Coach Corey Wayne
# 82599     The Cricket Podcast
# 82600     Sleepyhead Stories
#
#                                                 rss_link  \
# 0               https://anchor.fm/s/11b84b68/podcast/rss
# 1                https://anchor.fm/s/81a072c/podcast/rss
# 2                https://anchor.fm/s/917dba4/podcast/rss
# 3      https://www.fuckboisoflit.com/episodes?format=rss
# 4                https://anchor.fm/s/8afceec/podcast/rss
# ...                                                  ...
# 82596             http://thetop10.podomatic.com/rss2.xml
# 82597            https://anchor.fm/s/9043d60/podcast/rss
# 82598            https://anchor.fm/s/4dd625c/podcast/rss
# 82599            https://anchor.fm/s/9d3dcf0/podcast/rss
# 82600            https://anchor.fm/s/29d301c/podcast/rss
#
#                                   episode_uri  \
# 0      spotify:episode:000A9sRBYdVh66csG2qEdj
# 1      spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 2      spotify:episode:001i89SvIQgDuuyC53hfBm
# 3      spotify:episode:0025RWNwe2lnp6HcnfzwzG
# 4      spotify:episode:0025w0gdgkl11Nzkmg1wnm
# ...                                       ...
# 82596  spotify:episode:7zzQnjBXqDApvnm1hLPzVY
# 82597  spotify:episode:7zzRRsjuymax0YSczpi0SU
# 82598  spotify:episode:7zzZJGsL8fwDOrduUkX91D
# 82599  spotify:episode:7zzoT4r0Rhffyegk2HJ9N8
# 82600  spotify:episode:7zzq8sPfKAO4V7uIyhpbVd
#
#                                             episode_name  \
# 0                                1: It’s Christmas Time!
# 1      Ep.36 - Incorporating a Singular Goalkeeping C...
# 2                       Episode 1: Arrowhead Live! Debut
# 3      The Lion, The Witch, And The Wardrobe - Ashley...
# 4        Tourism in India : Opportunities and Challenges
# ...                                                  ...
# 82596          The Top 10 - Re-List - Steve Martin Moves
# 82597  Let's Grab Coffee E45 with Ross Paquette | Gro...
# 82598                      Maybe She Is Just Testing Me?
# 82599                           Ep 16: England In Danger
# 82600         The Tale Of Little Pig Robinson 🐖 (part 2)
#
#                                      episode_description   duration  \
# 0      On the first ever episode of Kream in your Kof...  12.700133
# 1      Today’s episode is a sit down Michael and Omar...  43.616333
# 2      Join us as we take a look at all current Chief...  58.189200
# 3      The modern morality tail of how to stay good f...  51.782050
# 4                                                     .   13.788000
# ...                                                  ...        ...
# 82596  Thanks to our patreon members for their suppor...  51.025850
# 82597  Ross founded Maropost in 2011 as a customer-ce...  33.364750
# 82598  How to know if your woman is maybe just testin...  11.799950
# 82599  In Episode 16, the boys evaluate England's per...  69.215350
# 82600  Little Pig Robinson finally makes it to the ma...  22.363133
#
#               show_filename_prefix episode_filename_prefix language  \
# 0      show_2NYtxEZyYelR6RMKmjfPLB  000A9sRBYdVh66csG2qEdj       en
# 1      show_6vZRgUFTYwbAA79UNCADr4  001UfOruzkA3Bn1SPjcdfa       en
# 2      show_5BvKEjaMSuvUsGROGi2S7s  001i89SvIQgDuuyC53hfBm       en
# 3      show_7w3h3umpH74veEJcbE6xf4  0025RWNwe2lnp6HcnfzwzG       en
# 4      show_5ljREb8VLogQLT7AKGwav1  0025w0gdgkl11Nzkmg1wnm       en
# ...                            ...                     ...      ...
# 82596  show_416U8ZhubKrFHq8ynOaxfH  7zzQnjBXqDApvnm1hLPzVY       en
# 82597  show_5rgmBAzsJ5znpV2b4WNDsb  7zzRRsjuymax0YSczpi0SU       en
# 82598  show_56CjYLQWyMx1MkOEQmlubi  7zzZJGsL8fwDOrduUkX91D       en
# 82599  show_7uddSH8MhaK3Q6YFlllbVZ  7zzoT4r0Rhffyegk2HJ9N8       en
# 82600  show_6r0bfT6lOLqDMh9ujnT1BW  7zzq8sPfKAO4V7uIyhpbVd       en
#
#                                      transcript_whisperx  transcript_length  \
# 0      Hello, hello, hello everyone. This is Katie an...               1716
# 1      Welcome to Inside the 18. Today's episode is a...               2017
# 2      Hey Cheese fans! Before we get started, I want...               1518
# 3      Sorry to interrupt the show, but I do have to ...               1707
# 4      This is All India Radio. In the program Spotli...               1755
# ...                                                  ...                ...
# 82596  Hey guys, this is John Rocha again. And Matt N...               1881
# 82597  What's going on everyone? This is George Khali...               2005
# 82598  Hi, I'm Coach Cory Wayne and this is my video ...               1850
# 82599  I think it should never be permitted to happen...               1699
# 82600  Welcome to Sleepyhead Stories today. We love t...               1377
#
#       transcript_googleasr
# 0
# 1
# 2
# 3
# 4
# ...                    ...
# 82596
# 82597
# 82598
# 82599
# 82600
#
# [82601 rows x 16 columns]
#      Unnamed: 0                             show_uri  \
# 0         39292  spotify:show:4F8rZfDar6BAPF7Gb5Y8p4
# 1         68685  spotify:show:63vGA37mcOYr7a2FISJouG
# 2         27441  spotify:show:0rwfoaIaZmEerjNBznckAz
# 3         93363  spotify:show:1vvxqI1vuu0caee2onlzea
# 4         89073  spotify:show:4053MooFmLA18LOnZvJtsJ
# ..          ...                                  ...
# 495       16826  spotify:show:4kDrnsi5UnX8uj2k0OML10
# 496       19666  spotify:show:1edI0qnZJwEDAY49gc9uBV
# 497       33778  spotify:show:7KcSeWjWi8WTi2m6MEgbiv
# 498       25641  spotify:show:6bRby2ak8EziSLldK75IB5
# 499       69894  spotify:show:6YimGTDjLMTwhnnVhoFiTk
#
#                                              show_name  \
# 0    The Dark Swamp: Horror Stories | Swamp Dweller...
# 1              Kings Pulse: A Sacramento Kings Podcast
# 2              Naylor's Natter in association with TDT
# 3                                           SUPERWHITE
# 4          The Guava Girl Podcast by Isabella Silverio
# ..                                                 ...
# 495                                              PILF
# 496                                    The Wanger Show
# 497                                 Juice WRLD is Dead
# 498                              JAZZIZ Backstage Pass
# 499                                   Get Out and SURF
#
#                                       show_description  \
# 0    Horror Stories to keep you up at night! Suppor...
# 1    An in-depth Sacramento Kings podcast hosted by...
# 2    "Naylor's natter...just talking to teachers"  ...
# 3    Most polarizing in all of Southern Utah! 2 dud...
# 4    The Guava Girl Podcast was created with the pu...
# ..                                                 ...
# 495  Welcome to PILF, with Jess, your friendly neig...
# 496  In 2016, Christian Ruvalcaba, Cody Hall, and B...
# 497  Issa podcast Support this podcast: https://anc...
# 498  JAZZIZ Backstage Pass offers you unparalleled ...
# 499  A Costa Rica Surf Culture Podcast.  Brought to...
#
#                           publisher  \
# 0                     Swamp Dweller
# 1    Brenden Nunes & Rich Ivanowski
# 2                       Phil Naylor
# 3                        SUPERWHITE
# 4                 Isabella Silverio
# ..                              ...
# 495                    PILF Podcast
# 496                 The Wanger Show
# 497                    Ben Meyerson
# 498                 Brian Zimmerman
# 499                       Joe Walsh
#
#                                          rss_link  \
# 0         https://anchor.fm/s/a507954/podcast/rss
# 1         https://anchor.fm/s/9b77e0c/podcast/rss
# 2         https://anchor.fm/s/85b24b4/podcast/rss
# 3         https://anchor.fm/s/7fa81a4/podcast/rss
# 4         https://anchor.fm/s/30d34ac/podcast/rss
# ..                                            ...
# 495       https://anchor.fm/s/701b574/podcast/rss
# 496  https://thewangershow.podomatic.com/rss2.xml
# 497      https://anchor.fm/s/12c09344/podcast/rss
# 498       https://anchor.fm/s/931b7f4/podcast/rss
# 499       https://anchor.fm/s/760140c/podcast/rss
#
#                                 episode_uri  \
# 0    spotify:episode:2sezWffKSCO1gJkJbRVok9
# 1    spotify:episode:53b7oxSccQxn3944gBUBjq
# 2    spotify:episode:21OdOBc3J1GBN4E0BefW49
# 3    spotify:episode:6tlnZWUFIL0NdaBlPJBFA9
# 4    spotify:episode:6ZfSHvekirPxpDJTwlSSFk
# ..                                      ...
# 495  spotify:episode:1EzthBju3gf0aAHJZVfihu
# 496  spotify:episode:1S0HgykewGcjjHY2uwABdY
# 497  spotify:episode:2Th95WRFLcKWqBmnKaAIT4
# 498  spotify:episode:1t8YylHIXjxlWE2qOiLs3U
# 499  spotify:episode:59ClKYpQ9xOUNhRsZJS8jQ
#
#                                           episode_name  \
# 0    The Dark Swamp: Horror Stories (Episode 117) I...
# 1      Buddy Hield extension updates w/ Jason Anderson
# 2                      Pupil Premium with Marc Rowland
# 3                        The VIP List Ft. Seanne Smith
# 4                                  40: 100k CASH MONTH
# ..                                                 ...
# 495  Ep. 13: Dating multiple cubs and managing feel...
# 496  The Wanger Show #126 - Frank & Dorina Join Us ...
# 497                                       Wagon wheels
# 498  JAZZIZ Backstage Pass: Dave Koz Salutes the Gr...
# 499  35: What Is Hurricane Season? (with Ryan Waldron)
#
#                                    episode_description   duration  ...  \
# 0    In this episode, I share 5 creepy as hell stor...  40.963100  ...
# 1             Buddy Hield extension talks are heati...  50.362533  ...
# 2    This week I am in conversation with Pupil Prem...  63.292950  ...
# 3    Dallin's better than all of you  Follow the po...  88.400683  ...
# 4    Welcome to Episode 40 of the Guava Girl Podcas...  37.174417  ...
# ..                                                 ...        ...  ...
# 495  Today I answer a question I get a lot - how I ...  22.439767  ...
# 496  On this episode of The Wanger Show WE CELEBRAT...  82.664583  ...
# 497  We hate Brody, he sucks.  ---   This episode i...  20.582950  ...
# 498  Joining host Brian Zimmerman on the podcast fo...  19.418117  ...
# 499  It’s Sunday night, September 1st 2019, and the...  28.166100  ...
#
#                                    transcript_whisperx transcript_length  \
# 0    Are you looking to make a podcast? Well, if yo...              1614
# 1    Welcome back to another episode of the Kings P...              1506
# 2    Nailers Natter, just talking to teachers. Talk...              1614
# 3    What's up, guys? We'd like to quickly shout ou...              1726
# 4    What is up Guava Girls? Welcome back to the Gu...              1814
# ..                                                 ...               ...
# 495  Hey everyone, do you want to make a podcast of...              1726
# 496  Hey everybody, Christian here to tell you abou...              1639
# 497  Hey guys, I'm Jake. And I'm Ben. And... Anchor...              1485
# 498  Jazz's backstage pass from the horn section. L...              1642
# 499  Hey, hey, how's it going? This is Joe Walsh br...              1821
#
#                                   transcript_googleasr  \
# 0    Are you looking to make a podcast? Well, if yo...
# 1    Sacramento there it is. Welcome back to anothe...
# 2    That turd just talking to teachers talking to ...
# 3    What's up, guys? We'd like to quickly shout ou...
# 4    What is up? Guava Girls? Welcome back to the g...
# ..                                                 ...
# 495  Hey everyone. Do you want to make a podcast of...
# 496  Hey everybody Christian here to tell you about...
# 497  Hey guys, I'm Jake and I'm Ben and anchor anch...
# 498  Jazz is backstage pass from the horn section. ...
# 499  Hey, how's it going? This is Joe offspring of ...
#
#     transcript_googleasr_length  uh_count_whisperx uh_count_googleasr  \
# 0                          1617                  0                  0
# 1                          1548                  5                  0
# 2                          1617                  0                  0
# 3                          1371                  0                  1
# 4                          1849                  0                  0
# ..                          ...                ...                ...
# 495                        1731                  8                  1
# 496                        1601                  0                  0
# 497                        1438                  4                  0
# 498                        1711                  0                  0
# 499                        1859                  1                  0
#
#      um_count_whisperx  um_count_googleasr  well_count_whisperx  \
# 0                    0                   0                    2
# 1                   15                   0                    4
# 2                    0                   0                    8
# 3                    7                   0                    5
# 4                    9                   0                    0
# ..                 ...                 ...                  ...
# 495                 14                   0                    3
# 496                  2                   0                    4
# 497                  6                   0                    6
# 498                  0                   0                    3
# 499                  0                   0                    9
#
#      well_count_googleasr
# 0                       2
# 1                       4
# 2                       9
# 3                       3
# 4                       0
# ..                    ...
# 495                     3
# 496                     3
# 497                     3
# 498                     3
# 499                    10
#
# [500 rows x 23 columns]
#        Unnamed: 0  duration  transcript_length  transcript_googleasr_length  \
# count      500.00    500.00             500.00                       500.00
# mean     54319.50     40.20            1669.85                      1676.56
# std      30601.22     19.82             278.02                       301.92
# min         86.00     10.09             148.00                        85.00
# 25%      27370.75     23.10            1524.00                      1536.25
# 50%      54241.50     38.21            1682.00                      1706.00
# 75%      82059.00     54.92            1848.00                      1867.50
# max     105307.00     89.72            2251.00                      2308.00
#
#        uh_count_whisperx  uh_count_googleasr  um_count_whisperx  \
# count             500.00              500.00             500.00
# mean                1.25                0.10               1.65
# std                 2.62                0.31               3.03
# min                 0.00                0.00               0.00
# 25%                 0.00                0.00               0.00
# 50%                 0.00                0.00               0.00
# 75%                 1.00                0.00               2.00
# max                18.00                2.00              24.00
#
#        um_count_googleasr  well_count_whisperx  well_count_googleasr
# count              500.00               500.00                500.00
# mean                 0.20                 3.48                  3.51
# std                  0.56                 2.76                  2.76
# min                  0.00                 0.00                  0.00
# 25%                  0.00                 1.00                  1.00
# 50%                  0.00                 3.00                  3.00
# 75%                  0.00                 5.00                  5.00
# max                  4.00                17.00                 17.00
